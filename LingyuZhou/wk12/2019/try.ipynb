# %%
import pandas as pd

# %%
with open('2019info.txt') as info:
    info=[x for x in info.read().split('#') if x!='']

info={x.split('\n')[0].strip():{y.strip().rsplit(' ',maxsplit=1)[0].strip().lower():int(y.strip().rsplit(' ',maxsplit=1)[1]) for y in x.split('\n')[1:] if len(y.rsplit(' ',maxsplit=1))>1} for x in info}

info
# Out:
# {'pol': {'calzedonia': 9,
#   'caroll': 9,
#   'intimissimi': 9,
#   'new york & company': 9,
#   'tezenis': 9,
#   'nine west': 8,
#   'bcbgmaxazria': 7,
#   'liverpool': 7,
#   'diane von furstenberg': 6,
#   'brooks brothers': 5,
#   'barneys new york': 4,
#   'furla': 4,
#   'new yorker': 3,
#   'max mara': 2,
#   'beanpole': 1,
#   'heilan home': 1,
#   'metersbonwe': 1,
#   'revolve': 1,
#   'elie tahari': 0,
#   'jessica simpson': 0,
#   'longchamp': 0,
#   'mexx': 0,
#   'pimkie': 0,
#   'tom ford': 0,
#   'youngor': 0,
#   'express': 20,
#   'li-ning': 19,
#   "claire's": 18,
#   'dillards': 17,
#   'dolce & gabbana': 17,
#   'eddie bauer': 17,
#   'ermenegildo zegna': 16,
#   'muji': 16,
#   'tory burch': 14,
#   'aeropostale': 13,
#   'll bean': 13,
#   'tommy bahama': 13,
#   'fanatics': 11,
#   'brunello cucinelli': 30,
#   'jd sports': 30,
#   'takko': 30,
#   'very': 29,
#   'desigual': 28,
#   "dick's sporting goods": 27,
#   'dsw': 27,
#   'anthropologie': 26,
#   'k-way': 26,
#   'urban oufitters': 26,
#   'matalan': 24,
#   'river island': 24,
#   'skechers': 24,
#   'neiman marcus': 23,
#   'sports direct': 23,
#   'famous footwear': 22,
#   'foot locker': 22,
#   'michael kors': 22,
#   'cole haan': 21,
#   'forever 21': 21,
#   'russell athletic': 40,
#   'carolina herrera': 39,
#   'j.crew': 39,
#   'diesel': 38,
#   'ito-yokado': 38,
#   'marni': 38,
#   'columbia sportswear': 37,
#   'falabella': 37,
#   's.oliver': 37,
#   'chanel': 36,
#   'merrell': 36,
#   'steve madden': 35,
#   'topvalu collection': 35,
#   'valentino': 35,
#   'triumph': 34,
#   'versace': 34,
#   'buckle': 33,
#   'burlington': 33,
#   "kohl's": 33,
#   'sandro': 33,
#   'joe fresh': 32,
#   'anta': 31,
#   'armani': 31,
#   'boohoo': 31,
#   "chico's": 31,
#   'ross dress for less': 31,
#   'tom tailor': 31,
#   'aldi süd': 50,
#   "bloomingdale's": 50,
#   'fossil': 50,
#   "macy's": 50,
#   'tj maxx': 50,
#   "hudson's bay": 49,
#   'saks fifth avenue': 49,
#   'aldi nord': 48,
#   'lacoste': 48,
#   'mrp apparel': 48,
#   "sainsbury's - tu clothing": 48,
#   'champion': 47,
#   'hanes': 47,
#   'lidl gb': 46,
#   'ted baker': 45,
#   'american eagle': 44,
#   'ugg': 44,
#   'abercrombie & fitch': 43,
#   'kik': 43,
#   'decathlon': 60,
#   'el corte inglés': 60,
#   'dressmann': 59,
#   'kmart - attention': 59,
#   'miu miu': 59,
#   'nordstrom': 59,
#   'prada': 59,
#   'mango': 58,
#   's group - prisma': 56,
#   "tod's": 55,
#   'cortefiel': 54,
#   'debenhams': 54,
#   'monsoon': 53,
#   "victoria's secret": 53,
#   'aldo': 52,
#   'costco - kirkland signature': 52,
#   'mizuno': 52,
#   'amazon': 51,
#   'jcpenney': 51,
#   'mammut': 51,
#   'hermès': 70,
#   'next': 70,
#   'asics': 69,
#   'bonprix': 69,
#   'dior': 69,
#   'under armour': 69,
#   'celine': 68,
#   'fendi': 68,
#   'louis vuitton': 68,
#   'marc jacobs': 68,
#   'primark': 68,
#   "lands' end": 67,
#   'loft': 67,
#   'new balance': 67,
#   'jack & jones': 66,
#   'vero moda': 66,
#   'john lewis': 65,
#   'monoprix': 65,
#   'gildan': 64,
#   'guess': 63,
#   'ralph lauren': 63,
#   'speedo': 63,
#   'carrefour - tex': 62,
#   'superdry': 62,
#   'clarks': 61,
#   'coach': 61,
#   'kate spade': 61,
#   'moncler': 61,
#   'salvatore ferragamo': 61,
#   'g-star raw': 80,
#   'target': 79,
#   'uniqlo': 79,
#   'george at asda': 78,
#   'lindex': 78,
#   'ovs': 78,
#   'lululemon': 76,
#   'topshop': 74,
#   'walmart': 74,
#   'tesco - f&f': 73,
#   'new look': 72,
#   'united colors of benetton': 71,
#   'converse': 90,
#   'jordan': 90,
#   'nike': 90,
#   'tchibo': 90,
#   'asos': 88,
#   'bershka': 88,
#   'massimo dutti': 88,
#   'pull & bear': 88,
#   'stradivarius': 88,
#   'zara': 88,
#   'hugo boss': 87,
#   'burberry': 86,
#   'calvin klein': 86,
#   'van heusen': 86,
#   'zalando': 86,
#   'tommy hilfiger': 86,
#   'esprit': 85,
#   'levi strauss & co': 83,
#   'patagonia': 83,
#   'the north face': 81,
#   'timberland': 81,
#   'vans': 81,
#   'wrangler': 81,
#   'bottega veneta': 100,
#   'gucci': 100,
#   'adidas': 99,
#   'reebok': 99,
#   'marks & spencer': 97,
#   'puma': 97,
#   'saint laurent': 95,
#   'c&a': 93,
#   'h&m': 92,
#   'banana republic': 91,
#   'gap': 91,
#   'old navy': 91},
#  'gov': {"bloomingdale's": 8,
#   'boohoo': 8,
#   'caroll': 8,
#   "chico's": 8,
#   'decathlon': 8,
#   "macy's": 8,
#   'aeropostale': 0,
#   'anthropologie': 0,
#   'barneys new york': 0,
#   'bcbgmaxazria': 0,
#   'beanpole': 0,
#   'brooks brothers': 0,
#   'chanel': 0,
#   "claire's": 0,
#   'cortefiel': 0,
#   'costco - kirkland signature': 0,
#   "dick's sporting goods": 0,
#   'dolce & gabbana': 0,
#   'eddie bauer': 0,
#   'elie tahari': 0,
#   'express': 0,
#   'fanatics': 0,
#   'forever 21': 0,
#   'fossil': 0,
#   'furla': 0,
#   'heilan home': 0,
#   'ito-yokado': 0,
#   'jessica simpson': 0,
#   "kohl's": 0,
#   'lacoste': 0,
#   'li-ning': 0,
#   'll bean': 0,
#   'longchamp': 0,
#   'matalan': 0,
#   'max mara': 0,
#   'merrell': 0,
#   'metersbonwe': 0,
#   'mexx': 0,
#   'michael kors': 0,
#   'muji': 0,
#   'new york & company': 0,
#   'new yorker': 0,
#   'nine west': 0,
#   'ross dress for less': 0,
#   's.oliver': 0,
#   'sandro': 0,
#   'skechers': 0,
#   'sports direct': 0,
#   'steve madden': 0,
#   'ted baker': 0,
#   'tom ford': 0,
#   'tom tailor': 0,
#   'tommy bahama': 0,
#   'tory burch': 0,
#   'triumph': 0,
#   'urban oufitters': 0,
#   'very': 0,
#   'youngor': 0,
#   'abercrombie & fitch': 17,
#   'aldo': 17,
#   'amazon': 17,
#   'armani': 17,
#   'buckle': 17,
#   'burlington': 17,
#   'calzedonia': 17,
#   'carolina herrera': 17,
#   'carrefour - tex': 17,
#   'celine': 17,
#   'champion': 17,
#   'clarks': 17,
#   'cole haan': 17,
#   'debenhams': 17,
#   'desigual': 17,
#   'diane von furstenberg': 17,
#   'diesel': 17,
#   'dillards': 17,
#   'el corte inglés': 17,
#   'ermenegildo zegna': 17,
#   'famous footwear': 17,
#   'fendi': 17,
#   'foot locker': 17,
#   'hanes': 17,
#   'hermès': 17,
#   'intimissimi': 17,
#   'j.crew': 17,
#   'jcpenney': 17,
#   'jd sports': 17,
#   'john lewis': 17,
#   'kik': 17,
#   'k-way': 17,
#   "lands' end": 17,
#   'liverpool': 17,
#   'marc jacobs': 17,
#   'marni': 17,
#   'mrp apparel': 17,
#   'neiman marcus': 17,
#   'new look': 17,
#   'nordstrom': 17,
#   'pimkie': 17,
#   'ralph lauren': 17,
#   'revolve': 17,
#   'river island': 17,
#   'speedo': 17,
#   'takko': 17,
#   'tezenis': 17,
#   'tj maxx': 17,
#   'ugg': 17,
#   'under armour': 17,
#   'uniqlo': 17,
#   'valentino': 17,
#   'american eagle': 25,
#   'asics': 25,
#   'dsw': 25,
#   'lidl gb': 25,
#   'mango': 25,
#   'superdry': 25,
#   'topvalu collection': 25,
#   'aldi nord': 33,
#   'aldi süd': 33,
#   'anta': 33,
#   'asos': 33,
#   'brunello cucinelli': 33,
#   'coach': 33,
#   'columbia sportswear': 33,
#   'dior': 33,
#   'g-star raw': 33,
#   'guess': 33,
#   "hudson's bay": 33,
#   'jack & jones': 33,
#   'joe fresh': 33,
#   'kate spade': 33,
#   'kmart - attention': 33,
#   'loft': 33,
#   'louis vuitton': 33,
#   'mammut': 33,
#   'miu miu': 33,
#   'mizuno': 33,
#   'moncler': 33,
#   'monoprix': 33,
#   'monsoon': 33,
#   'prada': 33,
#   'russell athletic': 33,
#   'saks fifth avenue': 33,
#   'salvatore ferragamo': 33,
#   'target': 33,
#   "tod's": 33,
#   'vero moda': 33,
#   'versace': 33,
#   'banana republic': 50,
#   'bershka': 50,
#   'calvin klein': 50,
#   'esprit': 50,
#   'falabella': 50,
#   'gap': 50,
#   'gildan': 50,
#   'levi strauss & co': 50,
#   'lindex': 50,
#   'massimo dutti': 50,
#   'new balance': 50,
#   'next': 50,
#   'old navy': 50,
#   'ovs': 50,
#   'patagonia': 50,
#   'primark': 50,
#   'pull & bear': 50,
#   's group - prisma': 50,
#   'stradivarius': 50,
#   'tesco - f&f': 50,
#   'tommy hilfiger': 50,
#   'topshop': 50,
#   'united colors of benetton': 50,
#   'van heusen': 50,
#   "victoria's secret": 50,
#   'zara': 50,
#   'adidas': 67,
#   'bonprix': 67,
#   'burberry': 67,
#   'converse': 67,
#   'dressmann': 67,
#   'george at asda': 67,
#   'jordan': 67,
#   'lululemon': 67,
#   'nike': 67,
#   'reebok': 67,
#   "sainsbury's - tu clothing": 67,
#   'tchibo': 67,
#   'walmart': 67,
#   'zalando': 67,
#   'c&a': 83,
#   'h&m': 83,
#   'the north face': 83,
#   'timberland': 83,
#   'vans': 83,
#   'wrangler': 83,
#   'bottega veneta': 100,
#   'gucci': 100,
#   'hugo boss': 100,
#   'marks & spencer': 100,
#   'puma': 100,
#   'saint laurent': 100},
#  'trace': {'s group - prisma': 7,
#   'joe fresh': 6,
#   'abercrombie & fitch': 5,
#   "tod's": 5,
#   'aldo': 1,
#   'bottega veneta': 1,
#   'burberry': 1,
#   'celine': 1,
#   'coach': 1,
#   'cole haan': 1,
#   'decathlon': 1,
#   'dior': 1,
#   'fendi': 1,
#   'fossil': 1,
#   'gucci': 1,
#   'ito-yokado': 1,
#   'kate spade': 1,
#   "lands' end": 1,
#   'louis vuitton': 1,
#   'marc jacobs': 1,
#   'merrell': 1,
#   'miu miu': 1,
#   'moncler': 1,
#   'ovs': 1,
#   'prada': 1,
#   'ralph lauren': 1,
#   's.oliver': 1,
#   'saint laurent': 1,
#   'superdry': 1,
#   'ugg': 1,
#   'aeropostale': 0,
#   'amazon': 0,
#   'american eagle': 0,
#   'anta': 0,
#   'anthropologie': 0,
#   'armani': 0,
#   'barneys new york': 0,
#   'bcbgmaxazria': 0,
#   'beanpole': 0,
#   "bloomingdale's": 0,
#   'boohoo': 0,
#   'brooks brothers': 0,
#   'brunello cucinelli': 0,
#   'buckle': 0,
#   'burlington': 0,
#   'calzedonia': 0,
#   'carolina herrera': 0,
#   'caroll': 0,
#   'carrefour - tex': 0,
#   'chanel': 0,
#   "chico's": 0,
#   "claire's": 0,
#   'cortefiel': 0,
#   'costco - kirkland signature': 0,
#   'desigual': 0,
#   'diane von furstenberg': 0,
#   "dick's sporting goods": 0,
#   'diesel': 0,
#   'dillards': 0,
#   'dolce & gabbana': 0,
#   'dsw': 0,
#   'eddie bauer': 0,
#   'el corte inglés': 0,
#   'elie tahari': 0,
#   'ermenegildo zegna': 0,
#   'express': 0,
#   'falabella': 0,
#   'famous footwear': 0,
#   'fanatics': 0,
#   'foot locker': 0,
#   'forever 21': 0,
#   'furla': 0,
#   'guess': 0,
#   'heilan home': 0,
#   'intimissimi': 0,
#   'j.crew': 0,
#   'jcpenney': 0,
#   'jd sports': 0,
#   'jessica simpson': 0,
#   'kik': 0,
#   'kmart - attention': 0,
#   "kohl's": 0,
#   'k-way': 0,
#   'lacoste': 0,
#   'li-ning': 0,
#   'liverpool': 0,
#   'll bean': 0,
#   'longchamp': 0,
#   "macy's": 0,
#   'mango': 0,
#   'marni': 0,
#   'max mara': 0,
#   'metersbonwe': 0,
#   'mexx': 0,
#   'michael kors': 0,
#   'monoprix': 0,
#   'monsoon': 0,
#   'mrp apparel': 0,
#   'muji': 0,
#   'neiman marcus': 0,
#   'new york & company': 0,
#   'new yorker': 0,
#   'nine west': 0,
#   'nordstrom': 0,
#   'revolve': 0,
#   'river island': 0,
#   'ross dress for less': 0,
#   'salvatore ferragamo': 0,
#   'sandro': 0,
#   'skechers': 0,
#   'sports direct': 0,
#   'steve madden': 0,
#   'takko': 0,
#   'ted baker': 0,
#   'tezenis': 0,
#   'tj maxx': 0,
#   'tom ford': 0,
#   'tom tailor': 0,
#   'tommy bahama': 0,
#   'topvalu collection': 0,
#   'tory burch': 0,
#   'triumph': 0,
#   'urban oufitters': 0,
#   'valentino': 0,
#   'versace': 0,
#   'walmart': 0,
#   'youngor': 0,
#   'zalando': 0,
#   'aldi süd': 20,
#   'bershka': 19,
#   'loft': 19,
#   'massimo dutti': 19,
#   'primark': 19,
#   'pull & bear': 19,
#   'stradivarius': 19,
#   'zara': 19,
#   'dressmann': 14,
#   'target': 14,
#   'george at asda': 13,
#   'mammut': 13,
#   'pimkie': 12,
#   'topshop': 12,
#   "victoria's secret": 12,
#   'aldi nord': 11,
#   "hudson's bay": 11,
#   'lidl gb': 11,
#   'matalan': 11,
#   'saks fifth avenue': 11,
#   'john lewis': 27,
#   "sainsbury's - tu clothing": 27,
#   'speedo': 27,
#   'calvin klein': 26,
#   'tommy hilfiger': 26,
#   'van heusen': 26,
#   'clarks': 25,
#   'debenhams': 25,
#   'hermès': 25,
#   'new look': 25,
#   'very': 25,
#   'jack & jones': 24,
#   'russell athletic': 24,
#   'vero moda': 24,
#   'asics': 22,
#   'hugo boss': 22,
#   'tesco - f&f': 22,
#   'columbia sportswear': 21,
#   'mizuno': 21,
#   'next': 21,
#   'under armour': 21,
#   'uniqlo': 21,
#   'levi strauss & co': 48,
#   'lindex': 48,
#   'marks & spencer': 48,
#   'united colors of benetton': 48,
#   'h&m': 46,
#   'new balance': 46,
#   'banana republic': 45,
#   'champion': 45,
#   'gap': 45,
#   'hanes': 45,
#   'old navy': 45,
#   'gildan': 44,
#   'puma': 44,
#   'bonprix': 42,
#   'tchibo': 41,
#   'lululemon': 40,
#   'asos': 60,
#   'c&a': 56,
#   'g-star raw': 52,
#   'adidas': 51,
#   'reebok': 51,
#   'the north face': 65,
#   'timberland': 65,
#   'vans': 65,
#   'wrangler': 65,
#   'converse': 62,
#   'jordan': 62,
#   'nike': 62,
#   'patagonia': 78,
#   'esprit': 73},
#  'know': {'aldo': 10,
#   'calzedonia': 10,
#   "chico's": 10,
#   'costco - kirkland signature': 10,
#   'decathlon': 10,
#   'intimissimi': 10,
#   'j.crew': 10,
#   'jd sports': 10,
#   "kohl's": 10,
#   'miu miu': 10,
#   'prada': 10,
#   'river island': 10,
#   'takko': 10,
#   'tezenis': 10,
#   'topshop': 10,
#   'american eagle': 9,
#   "bloomingdale's": 9,
#   'buckle': 9,
#   'burlington': 9,
#   'dsw': 9,
#   'fossil': 9,
#   'guess': 9,
#   'kik': 9,
#   "macy's": 9,
#   'mango': 9,
#   'michael kors': 9,
#   'monoprix': 9,
#   'muji': 9,
#   "sainsbury's - tu clothing": 9,
#   'speedo': 9,
#   'tj maxx': 9,
#   'ugg': 9,
#   'amazon': 7,
#   'diesel': 7,
#   'dillards': 7,
#   'loft': 7,
#   'marni': 7,
#   'merrell': 7,
#   'ross dress for less': 7,
#   'triumph': 7,
#   'valentino': 7,
#   'aeropostale': 6,
#   'aldi süd': 6,
#   'express': 6,
#   'famous footwear': 6,
#   'jack & jones': 6,
#   'k-way': 6,
#   'lacoste': 6,
#   'li-ning': 6,
#   'monsoon': 6,
#   'tom tailor': 6,
#   'topvalu collection': 6,
#   'vero moda': 6,
#   'anta': 4,
#   'chanel': 4,
#   'cole haan': 4,
#   'desigual': 4,
#   'eddie bauer': 4,
#   'fanatics': 4,
#   'forever 21': 4,
#   'll bean': 4,
#   'louis vuitton': 4,
#   'matalan': 4,
#   's.oliver': 4,
#   'sandro': 4,
#   'skechers': 4,
#   "tod's": 4,
#   'brunello cucinelli': 3,
#   'carolina herrera': 3,
#   'celine': 3,
#   "claire's": 3,
#   'dior': 3,
#   'fendi': 3,
#   'foot locker': 3,
#   'joe fresh': 3,
#   'john lewis': 3,
#   'marc jacobs': 3,
#   'neiman marcus': 3,
#   'new york & company': 3,
#   'nine west': 3,
#   'sports direct': 3,
#   'steve madden': 3,
#   'tommy bahama': 3,
#   'anthropologie': 1,
#   'armani': 1,
#   'bcbgmaxazria': 1,
#   'diane von furstenberg': 1,
#   'ermenegildo zegna': 1,
#   'revolve': 1,
#   'ted baker': 1,
#   'tory burch': 1,
#   'urban oufitters': 1,
#   'versace': 1,
#   'barneys new york': 0,
#   'beanpole': 0,
#   'brooks brothers': 0,
#   'caroll': 0,
#   'dolce & gabbana': 0,
#   'elie tahari': 0,
#   'furla': 0,
#   'heilan home': 0,
#   'jessica simpson': 0,
#   'liverpool': 0,
#   'longchamp': 0,
#   'max mara': 0,
#   'metersbonwe': 0,
#   'mexx': 0,
#   'new yorker': 0,
#   'pimkie': 0,
#   'tom ford': 0,
#   'youngor': 0,
#   "hudson's bay": 20,
#   'next': 20,
#   'russell athletic': 20,
#   'saks fifth avenue': 20,
#   'aldi nord': 19,
#   'mammut': 19,
#   'ralph lauren': 19,
#   "victoria's secret": 19,
#   'asics': 17,
#   'coach': 17,
#   'columbia sportswear': 16,
#   'bonprix': 14,
#   'carrefour - tex': 14,
#   'cortefiel': 14,
#   'ito-yokado': 14,
#   'lidl gb': 14,
#   'lindex': 14,
#   'new look': 14,
#   'salvatore ferragamo': 14,
#   'under armour': 14,
#   "dick's sporting goods": 13,
#   'el corte inglés': 13,
#   'falabella': 13,
#   'hermès': 13,
#   'kate spade': 13,
#   'kmart - attention': 13,
#   'mizuno': 13,
#   'nordstrom': 13,
#   'very': 13,
#   'boohoo': 11,
#   'champion': 11,
#   'clarks': 11,
#   'hanes': 11,
#   'jcpenney': 11,
#   "lands' end": 11,
#   'moncler': 11,
#   'mrp apparel': 11,
#   'ovs': 11,
#   's group - prisma': 11,
#   'superdry': 11,
#   'zalando': 11,
#   'lululemon': 30,
#   'primark': 30,
#   'abercrombie & fitch': 29,
#   'bottega veneta': 29,
#   'gucci': 29,
#   'saint laurent': 29,
#   'dressmann': 27,
#   'hugo boss': 27,
#   'united colors of benetton': 27,
#   'debenhams': 26,
#   'burberry': 24,
#   'gildan': 23,
#   'g-star raw': 23,
#   'walmart': 21,
#   'c&a': 40,
#   'levi strauss & co': 40,
#   'new balance': 40,
#   'patagonia': 40,
#   'uniqlo': 40,
#   'george at asda': 34,
#   'marks & spencer': 34,
#   'tesco - f&f': 34,
#   'converse': 33,
#   'jordan': 33,
#   'nike': 33,
#   'the north face': 33,
#   'timberland': 33,
#   'vans': 33,
#   'wrangler': 33,
#   'calvin klein': 31,
#   'tchibo': 31,
#   'van heusen': 31,
#   'tommy hilfiger': 31,
#   'h&m': 50,
#   'puma': 50,
#   'banana republic': 47,
#   'gap': 47,
#   'old navy': 47,
#   'esprit': 44,
#   'asos': 43,
#   'bershka': 41,
#   'massimo dutti': 41,
#   'pull & bear': 41,
#   'stradivarius': 41,
#   'target': 41,
#   'zara': 41,
#   'adidas': 59,
#   'reebok': 59}}

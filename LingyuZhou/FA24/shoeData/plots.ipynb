# %%
import pandas as pd
import os 
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Arial'

# %%
extend=pd.read_csv('wages_extend_month.csv')
charge=pd.read_csv('wages_charge_month.csv')

# %%
# Out:
# 0            NaN
# 1     -15.727983
# 2      50.348982
# 3       2.585056
# 4      -4.850758
#          ...
# 125          NaN
# 126          NaN
# 127    36.380952
# 128    10.227761
# 129   -47.563353
# Name: pschange, Length: 130, dtype: float64

# %%
plt.scatter(extend.avg_pay,extend.pschange, facecolor='none', edgecolors='k')
plt.ylim(top=100)
# Out:
# (-232.29166666666666, 100.0)

# %%
extend.conveyor
# Out:
# 0      A-1
# 1      A-1
# 2      A-1
# 3      A-1
# 4      A-1
#       ...
# 125    C-6
# 126    C-7
# 127    C-7
# 128    C-7
# 129    C-7
# Name: conveyor, Length: 130, dtype: object

# %%
extend.isna().any()
# Out:
# conveyor      False
# month         False
# all_salary    False
# workers       False
# avg_pay       False
# attrition      True
# cus1           True
# cus1ps         True
# cus2           True
# cus2ps         True
# cus3           True
# cus3ps         True
# cus4           True
# cus4ps         True
# cus5           True
# cus5ps         True
# allps         False
# cus1price      True
# cus2price      True
# cus3price      True
# avgprice       True
# minprice       True
# maxprice       True
# numbuyers     False
# numstyles     False
# numartno      False
# numbatches    False
# cus6           True
# cus6ps         True
# cus1share      True
# pschange       True
# stylesch       True
# artnoch        True
# mbordering     True
# mbleadtime     True
# mbpricing      True
# mbpay          True
# dtype: bool

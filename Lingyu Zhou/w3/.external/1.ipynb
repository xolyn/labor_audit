# %%
import pandas as pd
import os
# from sentence_transformers import SentenceTransformer
# from sklearn.cluster import AgglomerativeClustering
from tqdm import tqdm

# %%
def assign(q,orig:bool=False, cp="delete"):
    global df
    if orig==True:
        df.loc[df.Q==q,"CPCleaned"]=cp
    else:
        df.loc[df.QCleaned==q,"CPCleaned"]=cp
        
def getOriginalQ(cleanedQ):
    global df
    return df[df.QCleaned==cleanedQ].Q.value_counts()

def undo(combinedQ:str):
    global df
    df.loc[df.QCleaned==combinedQ,"QCleaned"]=df.loc[df.QCleaned==combinedQ,"Q"]

def groupSent(sentences, threshold=0.75):
    # Load pre-trained Sentence-BERT model
    model = SentenceTransformer('all-MiniLM-L6-v2')
    embeddings = model.encode(sentences,show_progress_bar=False)
    clustering = AgglomerativeClustering(n_clusters=None, affinity='cosine', linkage='average', distance_threshold=1-threshold)
    clustering.fit(embeddings)
    clusters = {}
    for sentence_id, cluster_id in enumerate(clustering.labels_):
        if cluster_id not in clusters:
            clusters[cluster_id] = []
        clusters[cluster_id].append(sentences[sentence_id])
    return [group for group in clusters.values()]

genSubRule=lambda lol: {x: sorted(t, key=lambda x: len(x))[0] for t in lol for x in t}

def getQNum(qstr):
    global df
    return len(df[df.QCleaned==qstr])

def tabCountry(q):
    global df
    return df[df.QCleaned==q].Country.value_counts()

# with open("grpdQ.txt","r") as txt:
#     grpdQ=eval(txt.read())

def replace(qset, brief=None):
    '''list of questions, replace all with shortest/given'''
    qset=[x.strip() for x in qset]
    global df
    if brief==None:
        brief=sorted(qset,key=lambda x : len(x))[0]
    rplcidx=list(df[df["QCleaned"].isin(qset)].index)
    df.loc[rplcidx,"QCleaned"]=brief
    # df.loc[rplcidx,"cleaned"]=1

def getCountry(q):
    global df
    return df[df.QCleaned==q].Country.unique()

def CPVC(n):
    print(CPCleanedUnique[n])
    return df[df.CPCleaned==CPCleanedUnique[n]].QCleaned.value_counts()

def discard(q):
    global df
    df.drop(df[df.QCleaned==q].index, inplace=True)

def getYear(q):
    return df[df.QCleaned==q].AssesmentDate.str[-4:].unique()

def collapse(qcleaned, country):
    global df
    return df[(df.QCleaned==qcleaned) & (df.Country==country)].Q.value_counts()

def tab(cpnum=None,cp=None):
    assert cpnum!=None or cp!=None, "pass in at least 1 param."
    if cpnum!=None:
        cp=CPCleanedUnique[cpnum]
    print(cp)
    global df
    filtered_df=df[df['CPCleaned']==cp]
    return pd.crosstab(filtered_df['Country'], filtered_df['QCleaned'],margins=True).transpose()

def discardYear(qcleaned, country, year:int=2021):
    global df
    df.loc[(df.QCleaned==qcleaned) & (df.Country==country) & (df.AssesmentDate.str[-4:]==str(year)),"CPCleaned"]="delete"

# %% [markdown]
# ----

# %%
df=pd.read_csv("D://OneDrive - Cornell University//JselZJOB//24SU//w3//r2.csv")

# %% [markdown]
# ---

# %%
tab(cp='wage information, use and deduction')
# Out:
# wage information, use and deduction
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# does the employer keep only one accurate payrol...           0         0
# does the employer keep only one accurate payrol...         584      2503
# has the employer made any unauthorized deductio...         584      2503
# inform workers about wage pay and deduction                584      2503
# All                                                       1752      7509
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# does the employer keep only one accurate payrol...      0        851       0
# does the employer keep only one accurate payrol...    161          0     474
# has the employer made any unauthorized deductio...    161        833     474
# inform workers about wage pay and deduction           161          0     474
# All                                                   483       1684    1422
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# does the employer keep only one accurate payrol...          0        0    851
# does the employer keep only one accurate payrol...        122     1802   5646
# has the employer made any unauthorized deductio...        119     1802   6476
# inform workers about wage pay and deduction               122     1802   5646
# All                                                       363     5406  18619

# %%
replace(["does the employer keep only one accurate payroll record/ book?","does the employer keep only one accurate payroll record?"])

# %%
tab(cp="documentation and protection of young workers")
# Out:
# documentation and protection of young workers
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# does the employer comply with documentation req...           0         0
# does the employer comply with requirements rega...         584         0
# does the employer cross-check worker's age and ...           0         0
# does the employer have a verification system in...           0         0
# does the employer have permission from the pare...           0         0
# does the employer keep a record of workers unde...         584      2237
# does the employer reliably verify the age of wo...         584      2503
# does the employer remediate child labour as req...           0         0
# does the employer require workers under age 18 ...           0         0
# All                                                       1752      4740
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# does the employer comply with documentation req...      0        833     474
# does the employer comply with requirements rega...      0          0       0
# does the employer cross-check worker's age and ...      0          0       0
# does the employer have a verification system in...      0        851       0
# does the employer have permission from the pare...      0          0       0
# does the employer keep a record of workers unde...    161          0       0
# does the employer reliably verify the age of wo...    161          0       0
# does the employer remediate child labour as req...      0          0      99
# does the employer require workers under age 18 ...    161          0       0
# All                                                   483       1684     573
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# does the employer comply with documentation req...          0        0   1307
# does the employer comply with requirements rega...          0        0    584
# does the employer cross-check worker's age and ...        122        0    122
# does the employer have a verification system in...          0        0    851
# does the employer have permission from the pare...        119        0    119
# does the employer keep a record of workers unde...          0     1802   4784
# does the employer reliably verify the age of wo...          0     1802   5050
# does the employer remediate child labour as req...          0        0     99
# does the employer require workers under age 18 ...          0        0    161
# All                                                       241     3604  13077

# %% [markdown]
# ---

# %%
discard("does the employer remediate child labour as required under the cba?")
#99 deleted; one unique item asked in some years in Jordan

# %%
replace(["does the employer have a verification system in place to ensure they do not hire child labour in accordance with the national law?",
        "does the employer reliably verify the age of workers prior to hiring?",
         "does the employer cross-check worker's age and documents as stipulated by national law?"],"Verify the age of workers before hiring")

# %%
replace(["does the employer keep a record of workers under 18 years of age?",
         "does the employer comply with documentation requirements for workers under age of 18?",
         "does the employer have permission from the parents or legal guardians of workers between the ages of 14 and 16, and approval from the ministry of labor?"],
         "Keep a record of workers under age of 18")

# %%
discard("does the employer comply with requirements regarding the certificate of fitness for workers under age 18?")
#1 unique item in Bangladesh
discard("does the employer require workers under age 18 to provide a medical certificate, and an employment certificate or permit delivered by the director of labor?")
# 1 unique item in Haiti

# %%
tab(cp="overtime")
# Out:
# overtime
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# does the employer comply with daily limits on o...           0         0
# does the employer comply with limits on overtim...         584         0
# does the employer comply with monthly limits on...           0         0
# does the employer comply with the monthly limit...           0         0
# does the employer comply with yearly limits on ...           0         0
# does the employer get permission from the labor...           0      2276
# does the employer get permission from the labou...           0      2259
# does the employer get written consent from wome...         584         0
# does the employer obtain authorization from the...           0         0
# does the employer prepare written instructions ...         584         0
# does the employer provide compensatory days off...         584         0
# does the employer schedule overtime on public h...           0         0
# is overtime in line with legal limits?                       0         0
# is overtime limited to 3 hours per day, 14 hour...           0         0
# is overtime limited to three hours per day and ...           0         0
# is overtime voluntary?                                     584      2503
# is overtime work limited to two hours per day?               0      2503
# is overtime worked only for reasons allowed by ...           0         0
# All                                                       2920      9541
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# does the employer comply with daily limits on o...      0          0       0
# does the employer comply with limits on overtim...    101          0       0
# does the employer comply with monthly limits on...      0          0       0
# does the employer comply with the monthly limit...      0          0       0
# does the employer comply with yearly limits on ...      0          0       0
# does the employer get permission from the labor...      0          0       0
# does the employer get permission from the labou...     80          0       0
# does the employer get written consent from wome...      0          0       0
# does the employer obtain authorization from the...     80          0       0
# does the employer prepare written instructions ...      0        833       0
# does the employer provide compensatory days off...      0          0       0
# does the employer schedule overtime on public h...      0          0       0
# is overtime in line with legal limits?                  0         18       0
# is overtime limited to 3 hours per day, 14 hour...      0        833       0
# is overtime limited to three hours per day and ...      0          0       0
# is overtime voluntary?                                161        833     474
# is overtime work limited to two hours per day?          0          0       0
# is overtime worked only for reasons allowed by ...     60          0       0
# All                                                   482       2517     474
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# does the employer comply with daily limits on o...          0     1802   1802
# does the employer comply with limits on overtim...          0        0    685
# does the employer comply with monthly limits on...          0     1555   1555
# does the employer comply with the monthly limit...          0      247    247
# does the employer comply with yearly limits on ...          0     1802   1802
# does the employer get permission from the labor...          0        0   2276
# does the employer get permission from the labou...        122        0   2461
# does the employer get written consent from wome...          0        0    584
# does the employer obtain authorization from the...          0        0     80
# does the employer prepare written instructions ...          0        0   1417
# does the employer provide compensatory days off...          2     1802   2388
# does the employer schedule overtime on public h...          2        0      2
# is overtime in line with legal limits?                      0        0     18
# is overtime limited to 3 hours per day, 14 hour...          0        0    833
# is overtime limited to three hours per day and ...        122        0    122
# is overtime voluntary?                                    119     1802   6476
# is overtime work limited to two hours per day?              0        0   2503
# is overtime worked only for reasons allowed by ...          0        0     60
# All                                                       367     9010  25311

# %%
replace(["is overtime work limited to two hours per day?",
         "is overtime limited to three hours per day and nine hours per week?",
         "is overtime limited to 3 hours per day, 14 hours per week?",
         "is overtime in line with legal limits?",
         "does the employer comply with daily limits on overtime hours worked?	",
         "does the employer comply with limits on overtime hours worked?",
         "is overtime worked only for reasons allowed by law?"],"Comply with legal limits on overtime hours")

# %%
replace(["does the employer get permission from the labour inspector before workers work overtime?",
         "does the employer get written consent from women to work at night?","Get permission/consent for overtime"])

# %%
replace(["does the employer comply with yearly limits on overtime hours worked?","Get permission/consent for overtime"])
# combine one unique item in Vietnam with dissimilar others....

# %%
discard("does the employer provide compensatory days off when workers work on weekly rest days?") ##1 unique item in Bangladesh
discard("does the employer schedule overtime on public holidays only under conditions permitted by law?") # 2 strange entries in Nicaragua
discard("does the employer obtain authorization from the department of labour before working on sundays?") #only asked in 2015-2018 in Haiti
discard("does the employer get permission from the labor inspector before suspending weekly rest days?") # 1 item only asked in Camboia

# %%
df.loc[(df.QCleaned=="does the employer prepare written instructions on overtime?") & (df.Country=="Indonesia"),"QCleaned"]="Get permission/consent for overtime"
# move 1 unique item in Indonesia to others

# %%
for i in ["does the employer comply with monthly limits on overtime hours worked?",
           "does the employer comply with the monthly limits on overtime hours worked?"]:
    discard(i)
#one unique question in Vietnam

# %%
discard("does the employer prepare written instructions on overtime?")

# %%
tab(cp="welfare facilities")
# Out:
# welfare facilities
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# adequate washing facilities                                584      2503
# does employer provide cups or other sanitary me...           0      2368
# does the employer comply with requirements rega...           0         0
# does the employer keep food samples for 24 hours?            0         0
# does the workplace have a functioning and acces...           0      2383
# does the workplace have adequate accessible toi...         584      2279
# does the workplace have adequate changing rooms...           0         0
# does the workplace have adequate day care facil...         584      1230
# does the workplace have adequate hand washing t...           0         0
# does the workplace have adequate shelters or re...         584         0
# does the workplace have all required facilities?             0         0
# does the workplace have an adequate eating area?            18         0
# does the workplace have an adequate lunch room,...         566         0
# does the workplace provide all workers a place ...           0         0
# is the workplace clean and tidy?                             0         0
# providing drinking water                                   584      2503
# when provided as in-kind payment, does the empl...           0         0
# All                                                       3504     13266
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# adequate washing facilities                           161        851     474
# does employer provide cups or other sanitary me...      0          0       0
# does the employer comply with requirements rega...      0          0       0
# does the employer keep food samples for 24 hours?       0          0       0
# does the workplace have a functioning and acces...      0          0       0
# does the workplace have adequate accessible toi...    161        833     474
# does the workplace have adequate changing rooms...      0          0     474
# does the workplace have adequate day care facil...      0          0     474
# does the workplace have adequate hand washing t...      0          0       0
# does the workplace have adequate shelters or re...      0          0       0
# does the workplace have all required facilities?      161          0       0
# does the workplace have an adequate eating area?      161        833     474
# does the workplace have an adequate lunch room,...      0          0       0
# does the workplace provide all workers a place ...      0        833       0
# is the workplace clean and tidy?                        5          0       0
# providing drinking water                              161        851     474
# when provided as in-kind payment, does the empl...      0          0     474
# All                                                   810       4201    3318
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# adequate washing facilities                               122        0   4695
# does employer provide cups or other sanitary me...          0        0   2368
# does the employer comply with requirements rega...          0     1802   1802
# does the employer keep food samples for 24 hours?           0      721    721
# does the workplace have a functioning and acces...          0        0   2383
# does the workplace have adequate accessible toi...        122     1802   6255
# does the workplace have adequate changing rooms...          0        0    474
# does the workplace have adequate day care facil...          0        0   2288
# does the workplace have adequate hand washing t...          0     1802   1802
# does the workplace have adequate shelters or re...          0        0    584
# does the workplace have all required facilities?           64        0    225
# does the workplace have an adequate eating area?          122        0   1608
# does the workplace have an adequate lunch room,...          0        0    566
# does the workplace provide all workers a place ...         53     1802   2688
# is the workplace clean and tidy?                            2        0      7
# providing drinking water                                  122     1802   6497
# when provided as in-kind payment, does the empl...          0        0    474
# All                                                       607     9731  35437

# %%
replace(["does the workplace have adequate hand washing taps?","adequate washing facilities	"])

# %%
replace(["does the workplace provide all workers a place to store their clothes?",
         "does the workplace have adequate changing rooms/lockers to meet the needs of workers?",
         "does the workplace have adequate shelters or rest rooms?",
         "does the workplace have all required facilities?"],"Adequate changing rooms/locker")

# %%
replace(["does the workplace have an adequate lunch room, and/or canteen?",
         "does the workplace have an adequate eating area?",
         "does the employer comply with requirements regarding canteen?",
         "does employer provide cups or other sanitary means\nfor drinking water?"],
         "Adequate eating area")

# %%
replace(["does the workplace have a functioning and accessible nursing room?","Adequate changing rooms/locker"])
#combine 1 unique item in Cambodia with others

# %%
discard("does the employer keep food samples for 24 hours?")

# %%
df.loc[(df.QCleaned=="is the workplace clean and tidy?"),"CPCleaned"]="working environment"

# %%
discard("when provided as in-kind payment, does the employer give workers enough food of decent quality?") # 1 unique in Joradn
discard("does the workplace have adequate day care facilities?") #only asked in Bangladesh, Cambodia, and Jordan

# %%
tab(cp="health services and first aid")
# Out:
# health services and first aid
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# do workers have a medical check within the firs...           0         0
# do workers have annual medical checks?                     584         0
# do workers receive free periodic health checks ...           0         0
# do workers undergo a medical examination before...           0      2386
# does the employer address safety and health ris...         584      2236
# does the employer comply with requirements on h...         584         0
# does the employer provide adequate first-aid fa...           0         0
# does the employer provide required medical serv...         584         0
# does the workplace have adequate trained first ...           0         0
# does the workplace have an adequately equipped ...           0      2503
# has the employer ensured there are a sufficient...         584      2271
# has the employer provided first-aid training fo...           0      2286
# has the employer provided rescue and first-aid ...          18         0
# has the employer trained workers on first aid a...         566         0
# mechanisms/committee for cooperation on osh                  0      2503
# All                                                       3504     14185
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# do workers have a medical check within the firs...    161          0       0
# do workers have annual medical checks?                156        834     474
# do workers receive free periodic health checks ...    161          0       0
# do workers undergo a medical examination before...      0          0       0
# does the employer address safety and health ris...    161        833       0
# does the employer comply with requirements on h...      0        833       0
# does the employer provide adequate first-aid fa...      0        851       0
# does the employer provide required medical serv...    161        833     474
# does the workplace have adequate trained first ...      0        833       0
# does the workplace have an adequately equipped ...      0          0       0
# has the employer ensured there are a sufficient...    161        833     474
# has the employer provided first-aid training fo...    161          0     474
# has the employer provided rescue and first-aid ...      0          0       0
# has the employer trained workers on first aid a...      0          0       0
# mechanisms/committee for cooperation on osh             0          0       0
# All                                                  1122       5850    1896
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# do workers have a medical check within the firs...          0        0    161
# do workers have annual medical checks?                    120        0   2168
# do workers receive free periodic health checks ...          0     1802   1963
# do workers undergo a medical examination before...          2        0   2388
# does the employer address safety and health ris...        122     1802   5738
# does the employer comply with requirements on h...        119     1802   3338
# does the employer provide adequate first-aid fa...          0        0    851
# does the employer provide required medical serv...          0     1802   3854
# does the workplace have adequate trained first ...          0        0    833
# does the workplace have an adequately equipped ...          0        0   2503
# has the employer ensured there are a sufficient...        122     1802   6247
# has the employer provided first-aid training fo...        119     1802   4842
# has the employer provided rescue and first-aid ...          0        0     18
# has the employer trained workers on first aid a...          0        0    566
# mechanisms/committee for cooperation on osh                 0        0   2503
# All                                                       604    10812  37973

# %%
replace(["has the employer trained workers on first aid and formed a first-aid team?",
         "has the employer provided rescue and first-aid training for workers?",
         "has the employer provided first-aid training for workers?"],
         "Provide first aid training for workers")

# %%
replace(["do workers receive free periodic health checks as required by law?",
         "do workers have annual medical checks?",
         "do workers undergo a medical examination before being employed?"],
         "Workers have medical checks as required by law")

# %%
df.loc[df.Q.str.contains("annual medical checks"), "QCleaned"]="Workers have annual medical checks Haiti"

# %%
df.loc[df.Q=="does the workplace have a functioning hiv/aids committee?", "QCleaned"]="does the employer comply with requirements on hiv/aids?"

# %%
getOriginalQ("does the employer comply with requirements on hiv/aids?")
# Out:
# does the workplace have a functioning hiv/aids committee?                    2503
# does the employer comply with the law on hiv/aids prevention and control?    1802
# does the employer comply with requirements on hiv/aids?                       851
# does the employer comply with national policy on hiv/aids?                    566
# does the employer comply with requirements on hiv/aids ?                      119
# Name: Q, dtype: int64

# %%
replace(["does the workplace have an adequately equipped and staffed infirmary?"],
        "does the employer provide required medical services?")
##move 1 in Cambodia to others

# %%
for i in ["does the workplace have adequate trained first aid officers?",
"does the employer provide adequate first-aid facilities?",
"do workers have a medical check within the first three months of hiring ?",
"Workers have annual medical checks Haiti"]:
    assign(i)

#unique items only in Haiti or Indonesia

# %%
tab(cp="union operations")
# Out:
# union operations
# Country                                   Bangladesh  Cambodia  Haiti  \
# QCleaned
# employer deducts union dues as requested         584      2240    161
# employer provides facility for union             584      2503      0
# union has access to workers                      584      2503    161
# All                                             1752      7246    322
#
# Country                                   Indonesia  Jordan  Nicaragua  \
# QCleaned
# employer deducts union dues as requested        833     474        119
# employer provides facility for union            833     474          0
# union has access to workers                     851     474        122
# All                                            2517    1422        241
#
# Country                                   Vietnam    All
# QCleaned
# employer deducts union dues as requested     1802   6213
# employer provides facility for union         1802   6196
# union has access to workers                  1802   6497
# All                                          5406  18906

# %%
tab(cp="regular hours")
# Out:
# regular hours
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# do regular daily and weekly working hours excee...           0         0
# do regular daily or weekly working hours exceed...         584         0
# do regular daily or weekly working hours exceed...           0      2503
# do regular daily working hours exceed 10 hours?              0         0
# do regular daily working hours exceed legal lim...           0         0
# do regular work shifts exceed the daily legal l...           0         0
# do regular working hours exceed 10 hours per da...           0         0
# do regular working hours exceed 11 hours per da...           0         0
# do the attendance records reflect the hours act...           0         0
# do the working time records reflect the hours a...         584      2260
# do workers have at least one day off per week?             584         0
# does the employer comply with daily break periods?         584         0
# does the employer comply with shift work requir...           0         0
# does the employer post the factory's working ho...           0         0
# does the employer provide required breastfeedin...           0         0
# does the employer provide required weekly rest ...           0      2243
# All                                                       2336      7006
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# do regular daily and weekly working hours excee...      0        851       0
# do regular daily or weekly working hours exceed...      0          0       0
# do regular daily or weekly working hours exceed...    156          0       0
# do regular daily working hours exceed 10 hours?         0          0       0
# do regular daily working hours exceed legal lim...      5          0       0
# do regular work shifts exceed the daily legal l...      0          0       0
# do regular working hours exceed 10 hours per da...      0          0       0
# do regular working hours exceed 11 hours per da...      0          0     474
# do the attendance records reflect the hours act...      0        835       0
# do the working time records reflect the hours a...    129          0     474
# do workers have at least one day off per week?        161          0       0
# does the employer comply with daily break periods?    161          0       0
# does the employer comply with shift work requir...      0          0       0
# does the employer post the factory's working ho...     81          0       0
# does the employer provide required breastfeedin...     60          0       0
# does the employer provide required weekly rest ...      0          0     474
# All                                                   753       1686    1422
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# do regular daily and weekly working hours excee...          0        0    851
# do regular daily or weekly working hours exceed...          0        0    584
# do regular daily or weekly working hours exceed...        120        0   2779
# do regular daily working hours exceed 10 hours?             0      247    247
# do regular daily working hours exceed legal lim...          0        0      5
# do regular work shifts exceed the daily legal l...          4        0      4
# do regular working hours exceed 10 hours per da...          0     1555   1555
# do regular working hours exceed 11 hours per da...          0        0    474
# do the attendance records reflect the hours act...          0        0    835
# do the working time records reflect the hours a...        122     1802   5371
# do workers have at least one day off per week?              0     1802   2547
# does the employer comply with daily break periods?        119     1802   2666
# does the employer comply with shift work requir...          2     1802   1804
# does the employer post the factory's working ho...          0        0     81
# does the employer provide required breastfeedin...          0        0     60
# does the employer provide required weekly rest ...        119        0   2836
# All                                                       486     9010  22699

# %%
replace(["do regular daily and weekly working hours exceed legal limits (40 hours per week; 7 hours a day, 6 days a week or 8 hours per day, 5 days a week)?",
         "do regular daily or weekly working hours exceed the legal limit (8 hours per day, 48 hours per week)?",
         "do regular daily or weekly working hours exceed the legal limit?",
         "do regular daily working hours exceed legal limits?",
         "do regular working hours exceed 10 hours per day, or 48 hours per week?",
         "do regular daily working hours exceed 10 hours?",
         "do regular working hours exceed 11 hours per day or 48 hours per week?"],
         "Regular daily work hours exceed legal limit")

# %%
replace(["do the attendance records reflect the hours actually worked?",
         "do the working time records reflect the hours actually worked?"],
         "Attendance records reflect hours actuallyed worked")

# %%
replace(["does the employer comply with daily break periods?",
         "does the employer provide required weekly rest periods?"],
         "Comply with rest periods")

# %%
for i in ["does the employer provide required breastfeeding breaks?",
          "does the employer post the factory's working hours (for all shifts, and including break times)?",
          "does the employer comply with shift work requirements?",
          "do workers have at least one day off per week?"]:
    assign(i)

# %%
discard("do regular work shifts exceed the daily legal limit?")

# %%
tab(cp="contracting procedures")
# Out:
# contracting procedures
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# do all workers (other than apprentices, badli o...         584         0
# do the migrant workers have valid work permits ...           0         0
# do workers have to pay anyone to get a job?                  0      2236
# do workers pay any recruitment fees?                         0         0
# does the employer comply with legal requirement...           0         0
# does the employer comply with legal requirement...           0         0
# does the employer comply with limits on the tri...         584      2241
# does the employer comply with national law conc...           0         0
# does the employer comply with requirements conc...           0         0
# does the employer comply with requirements conc...         227         0
# does the employer comply with requirements for ...           0         0
# does the employer comply with requirements for ...           0         0
# does the employer comply with the legal require...           0         0
# does the employer consider workers on limited d...           0         0
# does the employer include the entire period of ...           0      2503
# does the employer pay for the return trip of mi...           0         0
# has the employer taken sufficient steps to ensu...           0         0
# have you found non-compliance with legal requir...         357      1091
# is the probationary period applied only to perm...           0         0
# is the probationary period limited to 3 months?              0         0
# limits on the use of fixed term contracts                    0      2503
# All                                                       1752     10574
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# do all workers (other than apprentices, badli o...      0          0       0
# do the migrant workers have valid work permits ...      0          0     474
# do workers have to pay anyone to get a job?             0          0       0
# do workers pay any recruitment fees?                    0        833     474
# does the employer comply with legal requirement...      0        480       0
# does the employer comply with legal requirement...      0        833       0
# does the employer comply with limits on the tri...    161          0       0
# does the employer comply with national law conc...      0          0       0
# does the employer comply with requirements conc...      0        353       0
# does the employer comply with requirements conc...      0        353       0
# does the employer comply with requirements for ...      0        480       0
# does the employer comply with requirements for ...      0          0       0
# does the employer comply with the legal require...      0         18       0
# does the employer consider workers on limited d...      0        833     474
# does the employer include the entire period of ...      0          0       0
# does the employer pay for the return trip of mi...      0          0     474
# has the employer taken sufficient steps to ensu...      0          0     474
# have you found non-compliance with legal requir...      0          0       0
# is the probationary period applied only to perm...      0        833       0
# is the probationary period limited to 3 months?         0          0     474
# limits on the use of fixed term contracts               0          0       0
# All                                                   161       5016    2844
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# do all workers (other than apprentices, badli o...          0        0    584
# do the migrant workers have valid work permits ...          0        0    474
# do workers have to pay anyone to get a job?                 0        0   2236
# do workers pay any recruitment fees?                        0        0   1307
# does the employer comply with legal requirement...          0        0    480
# does the employer comply with legal requirement...          0        0    833
# does the employer comply with limits on the tri...          0     1802   4788
# does the employer comply with national law conc...          0     1802   1802
# does the employer comply with requirements conc...          0        0    353
# does the employer comply with requirements conc...        119        0    699
# does the employer comply with requirements for ...          0     1802   2282
# does the employer comply with requirements for ...          0     1802   1802
# does the employer comply with the legal require...          0        0     18
# does the employer consider workers on limited d...          0        0   1307
# does the employer include the entire period of ...          0        0   2503
# does the employer pay for the return trip of mi...          0        0    474
# has the employer taken sufficient steps to ensu...          0        0    474
# have you found non-compliance with legal requir...          0        0   1448
# is the probationary period applied only to perm...          0        0    833
# is the probationary period limited to 3 months?             0        0    474
# limits on the use of fixed term contracts                   0     1802   4305
# All                                                       119     9010  29476

# %%
replace(["do workers have to pay anyone to get a job?","do workers pay any recruitment fees?"])

# %%
replace(["does the employer comply with limits on the trial period for apprentices?",
         "is the probationary period applied only to permanent workers (pkwtt) and for no longer than 3 months?	",
         "is the probationary period limited to 3 months?",
         "Comply with limits on probationary period"])

# %%
replace(["does the employer comply with requirements concerning sub-contracted workers at the workplace?",
         "have you found non-compliance with legal requirements for compensation, contracts, osh and/or working time pertaining to non-production workers and/or sub-contracted workers?",
         "does the employer comply with legal requirements relating to outsourced workers?",
         "does the employer comply with national law concerning dispatched workers at the workplace?"],
         "Comply with requirements on subcontracted/outsourced workers")

# %%
replace(["limits on the use of fixed term contracts",
         "does the employer consider workers on limited duration contracts who work beyond their term as unlimited duration contract workers?",
         "do all workers (other than apprentices, badli or casual workers) have a service book?	"],
         "Limits on the use of fixed contracts or have contracts")

# %%
replace(["do the migrant workers have valid work permits and residence ids?"],
        "Comply with requirements on subcontracted/outsourced workers")
#move 1 in Jordan to others: on requirement for special type of workers

# %%
for i in ["has the employer taken sufficient steps to ensure that migrant workers do not pay any unauthorized fees?",
          "does the employer pay for the return trip of migrant workers who have been expelled from the country because of an invalid residence id?",
          "does the employer include the entire period of continuous employment when determining workers' entitlements to maternity leave, attendance bonus, seniority bonus, and/or annual leave?",
          "does the employer comply with the legal requirement relating to compensation for the non-permanent workers?",
          "does the employer comply with requirements for apprentices?",
          "does the employer comply with requirements concerning home workers?",
          "does the employer comply with legal requirements when subcontracting part of its work to another enterprise?"]:
    assign(i)

# %% [markdown]
# ---
# # export:

# %%
df.Tags=df.Tags.fillna("")

# %%
df.isna().any()
# Out:
# Country              False
# FactoryAssessedID    False
# AssesmentDate        False
# QuestID              False
# CP                   False
# Q                    False
# Finding              False
# Tags                 False
# disclosed            False
# CPCleaned            False
# QCleaned             False
# id                   False
# dtype: bool

# %%
df.to_stata("D://r2.dta", version=118)

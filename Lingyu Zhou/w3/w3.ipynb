# %%
import pandas as pd
import os
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
from tqdm import tqdm
from datetime import datetime

# %%
df=pd.read_csv("raw.csv")
df[["CP", "Q", "CPCleaned", "QCleaned"]]=df[["CP", "Q", "CPCleaned", "QCleaned"]].applymap(lambda x : x.replace("  ", " ").lower().strip())
CPCleanedUnique=list(df.CPCleaned.unique())

# %%
def assign(q,orig:bool=False, cp="delete"):
    global df
    if orig==True:
        df.loc[df.Q==q,"CPCleaned"]=cp
    else:
        df.loc[df.QCleaned==q,"CPCleaned"]=cp
        
def getOriginalQ(cleanedQ):
    global df
    return df[df.QCleaned==cleanedQ].Q.value_counts()

def undo(combinedQ:str):
    global df
    df.loc[df.QCleaned==combinedQ,"QCleaned"]=df.loc[df.QCleaned==combinedQ,"Q"]

def groupSent(sentences, threshold=0.75):
    # Load pre-trained Sentence-BERT model
    model = SentenceTransformer('all-MiniLM-L6-v2')
    embeddings = model.encode(sentences,show_progress_bar=False)
    clustering = AgglomerativeClustering(n_clusters=None, affinity='cosine', linkage='average', distance_threshold=1-threshold)
    clustering.fit(embeddings)
    clusters = {}
    for sentence_id, cluster_id in enumerate(clustering.labels_):
        if cluster_id not in clusters:
            clusters[cluster_id] = []
        clusters[cluster_id].append(sentences[sentence_id])
    return [group for group in clusters.values()]

genSubRule=lambda lol: {x: sorted(t, key=lambda x: len(x))[0] for t in lol for x in t}

def getQNum(qstr):
    global df
    return len(df[df.QCleaned==qstr])

def tabCountry(q):
    global df
    return df[df.QCleaned==q].Country.value_counts()

# with open("grpdQ.txt","r") as txt:
#     grpdQ=eval(txt.read())

def replace(qset, brief=None):
    '''list of questions, replace all with shortest/given'''
    qset=[x.strip() for x in qset]
    global df
    if brief==None:
        brief=sorted(qset,key=lambda x : len(x))[0]
    rplcidx=list(df[df["QCleaned"].isin(qset)].index)
    df.loc[rplcidx,"QCleaned"]=brief
    # df.loc[rplcidx,"cleaned"]=1

def getCountry(q):
    global df
    return df[df.QCleaned==q].Country.unique()

def CPVC(n):
    print(CPCleanedUnique[n])
    return df[df.CPCleaned==CPCleanedUnique[n]].QCleaned.value_counts()

def discard(q):
    global df
    df.drop(df[df.QCleaned==q].index, inplace=True)

def getYear(q):
    return df[df.QCleaned==q].AssesmentDate.str[-4:].unique()

def collapse(qcleaned, country):
    global df
    return df[(df.QCleaned==qcleaned) & (df.Country==country)].Q.value_counts()

def tab(cpnum=None,cp=None):
    assert cpnum!=None or cp!=None, "pass in at least 1 param."
    if cpnum!=None:
        cp=CPCleanedUnique[cpnum]
    print(cp)
    global df
    filtered_df=df[df['CPCleaned']==cp]
    return pd.crosstab(filtered_df['Country'], filtered_df['QCleaned'],margins=True).transpose()

def discardYear(qcleaned, country, year:int=2021):
    global df
    df.loc[(df.QCleaned==qcleaned) & (df.Country==country) & (df.AssesmentDate.str[-4:]==str(year)),"CPCleaned"]="delete"

def exportStata(path=datetime.now().strftime("%Y%m%d%H%M")):
    df.to_stata(path, version=118)

# %% [markdown]
# # [convert](./convert.txt)

# %% [markdown]
# # grouping:
# ## machine grouping:

# %%
for i in CPCleanedUnique:
    print(df[df.CPCleaned==i].QCleaned.nunique(), "\t",i,sep="")
# Out:
# 33	other grounds
# 32	worker protection
# 22	emergency preparedness
# 4	hazardous work and other worst forms
# 24	chemicals and hazardous substances
# 18	dialogue, discipline and disputes
# 28	paid leave
# 8	working environment
# 14	gender
# 13	minimum wages/piece rate wages
# 22	leave
# 37	social security and other benefits
# 5	collective bargaining
# 16	worker accommodation
# 8	method of payment
# 1	forced labour and overtime
# 8	interference and discrimination
# 11	coercion
# 25	termination
# 7	race and origin
# 11	religion and political opinion
# 2	freedom to associate
# 1	bonded labour
# 14	employment contracts
# 21	contracting procedures
# 16	regular hours
# 3	union operations
# 15	health services and first aid
# 17	welfare facilities
# 18	overtime
# 9	documentation and protection of young workers
# 4	premium pay
# 4	wage information, use and deduction
# 26	osh management systems
# 16	overtime wages
# 4	strikes
# 1	child labourers
# 4	prison labour

# %%
for i in tqdm(CPCleanedUnique):
    if i not in ['union operations','freedom to associate','strikes','collective bargaining','interference and discrimination']:
        if df[df.CPCleaned==i].QCleaned.nunique()>1: # otherwise ml model stop due to error
            ruleList=groupSent(df[df.CPCleaned==i].QCleaned.unique())
            for j in ruleList:
                if sum([len(df[df.QCleaned==x]) for x in j])<=6476:
                    replace(j)
        # break

# %% [markdown]
# # manually grouping:

# %%
# undo("has the employer taken legally required measures to help workers with hiv/ aids-related illnesses?")

# undo("is sexual orientation a factor in decisions regarding pay?")

# undo("is an applicant's sexual orientation a factor in hiring decisions?")

# replace(['does the employer allow workers with aids-related illnesses to work for as long as medically fit in available, appropriate work?',
# 'does the employer allow workers with hiv/aids-related illnesses to work for as long as medically fit in available, appropriate work?']
# )

# replace(['has the employer taken all legally required measures to reasonably help workers with aids-related illnesses?',
# 'has the employer taken legally required measures to help workers with hiv/ aids-related illnesses?'])

# replace([
#     'is age a factor in hiring, employment, or termination?',
#     "is an applicant's age a factor in hiring decisions?"
# ])

# replace([
#     "is a worker's real or perceived hiv/aids status a factor in decisions regarding termination or retirement?",
# "is a worker's real or perceived hiv/aids status a factor in the employer's decisions regarding termination or retirement?"
# ])

# replace(["have all accommodations required by national law been made for physically disabled persons?",
# "has the employer made required accommodations for physically disabled workers?"])

# replace(["does the employer hire one disabled worker for every 100 workers?	",
#          "does the employer comply with legal requirements regarding the hiring of disabled workers?"],
#          "compliance on hiring disabled workers")

# %%
tab(0)
# Out:
# other grounds
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# are a worker's family responsibilities a factor...           0         0
# are disabled persons who apply for work evaluat...           0      2237
# are family responsibilities a factor in decisio...           0         0
# are family responsibilities a factor in decisio...           0         0
# are hiv/aids tests required at hiring?                       0         0
# are workers harassed on the basis of their fami...           0         0
# compliance on hiring disabled workers                        0         3
# do recruitment materials such as job announceme...           0         0
# does the employer allow workers with aids-relat...           0         0
# has the employer made required accommodations f...           0      2236
# has the employer taken legally required measure...           0         0
# is a worker's real or perceived hiv/aids status...           0      2236
# is age a factor in decisions regarding opportun...           0         0
# is age a factor in decisions regarding pay?                  0         0
# is an applicant's age a factor in hiring decisi...           0         0
# is an applicant's family responsibilities a fac...           0         0
# is an applicant's real or perceived hiv/aids st...           0      2236
# is an applicant's sexual orientation a factor i...           0         0
# is disability a factor in decisions regarding c...           0      2236
# is disability a factor in decisions regarding pay?         584      2236
# is disability a factor in the employer's decisi...           0      2236
# is disability a factor that affects decisions a...           0      2236
# is hiv/aids status a factor in decisions regard...           0      2236
# is hiv/aids status a factor in decisions regard...           0      2236
# is hiv/aids status a factor in decisions regard...           0      2236
# is sexual orientation a factor in decisions reg...           0         0
# is sexual orientation a factor in decisions reg...           0         0
# is sexual orientation a factor in decisions reg...           0         0
# is sexual orientation a factor in the employer'...           0         0
# is there harassment of workers on the basis of ...           0         0
# is there harassment of workers on the basis of ...           0      2236
# is there harassment of workers on the basis of ...           0      2236
# is there harassment of workers on the basis of ...           0         0
# All                                                        584     29072
#
# Country                                             Indonesia  Jordan  \
# QCleaned
# are a worker's family responsibilities a factor...          0       0
# are disabled persons who apply for work evaluat...          0       0
# are family responsibilities a factor in decisio...          0       0
# are family responsibilities a factor in decisio...          0       0
# are hiv/aids tests required at hiring?                      0       0
# are workers harassed on the basis of their fami...          0       0
# compliance on hiring disabled workers                     851     474
# do recruitment materials such as job announceme...          0       0
# does the employer allow workers with aids-relat...          0       0
# has the employer made required accommodations f...        833       0
# has the employer taken legally required measure...          0       0
# is a worker's real or perceived hiv/aids status...          0       0
# is age a factor in decisions regarding opportun...          0       0
# is age a factor in decisions regarding pay?                 0       0
# is an applicant's age a factor in hiring decisi...          0       0
# is an applicant's family responsibilities a fac...          0       0
# is an applicant's real or perceived hiv/aids st...          0       0
# is an applicant's sexual orientation a factor i...          0       0
# is disability a factor in decisions regarding c...          0       0
# is disability a factor in decisions regarding pay?          0       0
# is disability a factor in the employer's decisi...        833       0
# is disability a factor that affects decisions a...        833       0
# is hiv/aids status a factor in decisions regard...          0       0
# is hiv/aids status a factor in decisions regard...          0       0
# is hiv/aids status a factor in decisions regard...          0       0
# is sexual orientation a factor in decisions reg...          0       0
# is sexual orientation a factor in decisions reg...          0       0
# is sexual orientation a factor in decisions reg...          0       0
# is sexual orientation a factor in the employer'...          0       0
# is there harassment of workers on the basis of ...          0       0
# is there harassment of workers on the basis of ...        833       0
# is there harassment of workers on the basis of ...          0       0
# is there harassment of workers on the basis of ...          0       0
# All                                                      4183     474
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# are a worker's family responsibilities a factor...          0       27     27
# are disabled persons who apply for work evaluat...        119     1802   4158
# are family responsibilities a factor in decisio...          0       27     27
# are family responsibilities a factor in decisio...          0       54     54
# are hiv/aids tests required at hiring?                      0     1802   1802
# are workers harassed on the basis of their fami...          0       27     27
# compliance on hiring disabled workers                       0        0   1328
# do recruitment materials such as job announceme...          0      721    721
# does the employer allow workers with aids-relat...          2     1802   1804
# has the employer made required accommodations f...        119     1802   4990
# has the employer taken legally required measure...        119     1802   1921
# is a worker's real or perceived hiv/aids status...        119     1802   4157
# is age a factor in decisions regarding opportun...          0      721    721
# is age a factor in decisions regarding pay?                 0     1442   1442
# is an applicant's age a factor in hiring decisi...          0     1469   1469
# is an applicant's family responsibilities a fac...          0       54     54
# is an applicant's real or perceived hiv/aids st...        119     1802   4157
# is an applicant's sexual orientation a factor i...        119      721    840
# is disability a factor in decisions regarding c...        119     1802   4157
# is disability a factor in decisions regarding pay?        119     1802   4741
# is disability a factor in the employer's decisi...        119     1802   4990
# is disability a factor that affects decisions a...        119     1802   4990
# is hiv/aids status a factor in decisions regard...        119     1802   4157
# is hiv/aids status a factor in decisions regard...        119     1802   4157
# is hiv/aids status a factor in decisions regard...        119     1802   4157
# is sexual orientation a factor in decisions reg...        119      721    840
# is sexual orientation a factor in decisions reg...        119      721    840
# is sexual orientation a factor in decisions reg...        119      721    840
# is sexual orientation a factor in the employer'...        119      721    840
# is there harassment of workers on the basis of ...          0      721    721
# is there harassment of workers on the basis of ...        119     1802   4990
# is there harassment of workers on the basis of ...        119     1802   4157
# is there harassment of workers on the basis of ...        119      721    840
# All                                                      2382    38421  75116

# %%
#1:

# replace(['are electrical wires, switches and plugs properly installed, grounded, and maintained?',
#          'are electrical wires, cables, switches, plugs and equipment (e.g. transformer, generator, electrical panel, circuit breakers) properly installed, grounded (for equipment), and maintained?'])

# replace(['are workers effectively trained and encouraged to use the personal protective equipment that is provided?	',
#          'are workers effectively trained and encouraged to properly use personal protective equipment and machines?'])

# replace(
#     ['are workers effectively trained to use the personal protective equipment and machines?',
# 'are workers effectively trained and encouraged to properly use personal protective equipment, machines and equipment?',
# 'are workers effectively trained and encouraged to properly use the personal protective equipment and machines?',
# 'are workers effectively trained and encouraged to use the personal protective equipment that is provided?',
# 'are workers effectively trained on occupational health and safety?',
# 'are workers effectively trained to use the personal protective equipment and machines?',
# 'are workers effectively trained to use the personal protective equipment that is provided?',
# 'are all workers trained and obligated to use machines and equipment safely?']
# )

# undo("are boilers registered or certified, as legally required?")

# replace(["do workers have suitable chairs?",
# "does the employer comply with ergonomic requirements?"])

# replace(["are electrical wires, cables, switches, plugs and equipment (e.g. transformer, generator, electrical panel, circuit breakers, electrical boilers) properly installed, grounded (for equipment), maintained, and certified?",
# "are electrical wires, cables, switches, plugs, and equipment (e.g. transformer, generator, electrical panel, circuit breakers) properly installed, grounded (for equipment), and maintained?",
# "are electrical wires, switches and plugs properly installed, grounded, and maintained?",
# "are electrical boxes, electrical wires, switches and plugs properly installed, grounded, and maintained?",
# "are electrical wires, switches and plugs properly installed, grounded, maintained and certified?",
# "are electrical wires, switches, plugs and appliances properly installed, grounded, and maintained?",
# "are electrical wires, switches, plugs and appliances properly installed, grounded, regularly checked and maintained?"])

# replace(["do the operators / technicians for boiler, generator, compressor, and pressure vessels have legally required permit and training?",
# "do steam generating machine operators have valid licenses?",
# "are boilers registered or certified, as legally required?",
# "do the operators/ technicians/ officers responsible for machinery/ equipment/ installations/ lifting equipment have the required license?",
# "do the technicians for electrical installations and boiler operators have the legally required license/ certification?"],
# "boiler or steam operator certified")

# replace(["are workers punished if they remove themselves from work situations that they believe present an imminent and serious danger to life or health?",
# "does the employer force workers to continue working when they have refused to work due to clear imminent and serious danger to their life or health?"],"prevent workers away from dangerous workplaces")

# replace(["does the employer provide workers with all necessary personal protective clothing and equipment?",
# "does the employer provide workers with all necessary personal protective clothing and equipment?"])

# undo("does the employer comply with legal requirements related to work subject to strict\noccupational safety requirements?")

# replace(["does the employer comply with legal requirements related to work subject to strict\noccupational safety requirements?",
# "does the employer comply with legal requirements related to work subject to strict occupational safety requirements?"])

# replace([
#     "does the employer comply with legal requirements related to machines and equipment subject to strict occupational safety requirements?",
# "does the employer comply with legal requirements related to machines, equipment subject to strict occupational safety requirements?"
# ])

# replace(['does the employer provide  workers with all necessary personal protective clothing and equipment?',
#        'does the employer provide workers with all necessary personal protective clothing and equipment?'])

# replace(["does the employer provide workers with all necessary personal protective clothing and equipment?",
# "has the employer provided workers who work with chemical substances with proper clothing and personal protective equipment when necessary?"])

# replace([
#     "boiler or steam operator certified",
#     "do workers use the personal protective equipment that is provided?"
# ])

# for i in ["has the employer provided workers with dust masks when necessary?",
# "has the employer provided workers with ear plugs when necessary?",
# "has the employer provided workers with metal gloves when necessary?",
# "has the employer provided workers with necessary ppe to protect against wet processes when necessary?",
# "has the employer provided workers with other ppe when necessary?",
# "has the factory conducted an assessment of the potential hazards in the workplace?	"]:
#     assign(i)

# df.loc[df.Q=="do the technicians for electrical installations and boiler operators have the legally required license/ certification?","QCleaned"]=\
# "do the technicians for electrical installations and boiler operators have the legally required license/ certification?"


# for i in [
# "do workers use the machines and equipment in a safe manner?",
# "does the employer comply with legal requirements related to machines, equipment subject to strict occupational safety requirements?",
# "does the employer comply with legal requirements related to work subject to strict\noccupational safety requirements?",
# "has the factory conducted an assessment of the potential hazards in the workplace?",
# "is the workplace overcrowded?"
# ]:
#     assign(i)

# %%
# df[(df.QCleaned=="are electrical wires, switches and plugs properly installed, grounded, and maintained?") & (df.Country=="Indonesia")].Q.value_counts()
# df[(df.QCleaned=="boiler or steam operator certified") & (df.Country=="Bangladesh")].Q.value_counts()
tab(1)
# Out:
# worker protection
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# are all workers trained and obliged to use the ...           0         0
# are appropriate safety warnings posted in the w...         584      2503
# are electrical wires, switches and plugs proper...         584      2503
# are proper guards installed and maintained on a...         584      2503
# are workers effectively trained on occupational...         584      2286
# are workers protected against falls from heights?          357      2241
# boiler or steam operator certified                         357      2434
# do the technicians for electrical installations...         357         0
# do workers have suitable chairs?                           584      2321
# does the employer provide workers with all nece...         584      2503
# prevent workers away from dangerous workplaces             584      2503
# All                                                       5159     21797
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# are all workers trained and obliged to use the ...      0        834       0
# are appropriate safety warnings posted in the w...    161        833     474
# are electrical wires, switches and plugs proper...    161        838     474
# are proper guards installed and maintained on a...    161        833     474
# are workers effectively trained on occupational...    161        833     474
# are workers protected against falls from heights?       0        480       0
# boiler or steam operator certified                      0        834       0
# do the technicians for electrical installations...      0          0       0
# do workers have suitable chairs?                      161        833     474
# does the employer provide workers with all nece...    161        851     474
# prevent workers away from dangerous workplaces        161        851     474
# All                                                  1127       8020    3318
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# are all workers trained and obliged to use the ...          0        0    834
# are appropriate safety warnings posted in the w...        119     1802   6476
# are electrical wires, switches and plugs proper...        122     1802   6484
# are proper guards installed and maintained on a...        119     1802   6476
# are workers effectively trained on occupational...        119     1802   6259
# are workers protected against falls from heights?           0     1802   4880
# boiler or steam operator certified                        122     1802   5549
# do the technicians for electrical installations...          0        0    357
# do workers have suitable chairs?                          122     1802   6297
# does the employer provide workers with all nece...        122     1802   6497
# prevent workers away from dangerous workplaces              0     1802   6375
# All                                                       845    16218  56484

# %%
#2:

# replace(["does the workplace have adequate and accessible fire-fighting equipment?",
# "does the workplace have adequate fire-fighting equipment?"])

# replace(["does the workplace have adequate fire-fighting equipment and within easy reach of workers?",
# "does the workplace have adequate fire-fighting equipment that is within easy reach of workers?"])

# replace([
#     "does the workplace have adequate fire-fighting equipment and within easy reach of workers?",
# "does the workplace have adequate fire-fighting equipment?"
# ])

# replace([
#     "has the employer appointed and trained a fire management team?	",
#     "has the employer trained at least 80% of workers to use the fire-fighting equipment?"
# ])

# for i in [
#     "accessable unlocked emergency exits",
#     "are emergency exits and escape routes clearly marked?",
#           "at least 2 possible emergency exits","fire detection and alarm system","periodic emergency drills"]:
#     discardYear(i,"Nicaragua")

# for i in [
#     "accessable unlocked emergency exits",
#           "at least 2 possible emergency exits","fire detection and alarm system",
#           "does the workplace have adequate fire-fighting equipment?",
#           "has the employer appointed and trained a fire management team?",
#           "periodic emergency drills"]:
#     discardYear(i,"Indonesia")

replace([
    "has the employer appointed and trained a fire management team?",
    "has the employer trained an appropriate number of workers to use the fire-fighting equipment?"
])

# %%
tab(2)
# Out:
# emergency preparedness
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# accessable unlocked emergency exits                        584      2503
# are emergency exits and escape routes clearly m...         584      2296
# are escape routes free of obstruction?                       0      2503
# are flammable materials safely stored?                     584      2254
# are floors and corridors in line with legal req...           0         0
# are possible sources of ignition appropriately ...         584      2241
# are the emergency exits locked during working h...           0      2503
# at least 2 possible emergency exits                        584      2503
# does the employer comply with emergency require...         357         0
# does the employer comply with size requirements...           0         0
# does the workplace have adequate fire-fighting ...         584      2503
# does the workplace have adequate stairways that...         584         0
# does the workplace have at least one adequate w...         566         0
# fire detection and alarm system                            584      2503
# has the employer appointed and trained a fire m...         584      2503
# has the employer elaborated and implemented an ...           0         0
# periodic emergency drills                                  584      2503
# All                                                       6763     26815
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# accessable unlocked emergency exits                   161        833     474
# are emergency exits and escape routes clearly m...    161        833     474
# are escape routes free of obstruction?                  0          0       0
# are flammable materials safely stored?                161        833     474
# are floors and corridors in line with legal req...      0          0       0
# are possible sources of ignition appropriately ...    161        833     474
# are the emergency exits locked during working h...      0          0       0
# at least 2 possible emergency exits                   161        833     474
# does the employer comply with emergency require...      0        480       0
# does the employer comply with size requirements...      0          0       0
# does the workplace have adequate fire-fighting ...    161        833     474
# does the workplace have adequate stairways that...      0          0       0
# does the workplace have at least one adequate w...      0          0       0
# fire detection and alarm system                       161        833     474
# has the employer appointed and trained a fire m...    155        833     474
# has the employer elaborated and implemented an ...      0          0       0
# periodic emergency drills                             161        833     474
# All                                                  1443       7977    4266
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# accessable unlocked emergency exits                       119     1802   6476
# are emergency exits and escape routes clearly m...        119     1802   6269
# are escape routes free of obstruction?                      0        0   2503
# are flammable materials safely stored?                    117     1802   6225
# are floors and corridors in line with legal req...        117        0    117
# are possible sources of ignition appropriately ...        117     1802   6212
# are the emergency exits locked during working h...          0        0   2503
# at least 2 possible emergency exits                       119     1802   6476
# does the employer comply with emergency require...          0        0    837
# does the employer comply with size requirements...          0     1802   1802
# does the workplace have adequate fire-fighting ...        119     1802   6476
# does the workplace have adequate stairways that...          0        0    584
# does the workplace have at least one adequate w...          0        0    566
# fire detection and alarm system                           119     1802   6476
# has the employer appointed and trained a fire m...        119     1802   6470
# has the employer elaborated and implemented an ...        119     1802   1921
# periodic emergency drills                                 119     1802   6476
# All                                                      1303    19822  68389

# %%
tab(3)
# Out:
# hazardous work and other worst forms
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# are any workers under age 18 subjected to the u...         584      2236
# are any workers who are under age 18 working at...         584      2236
# are any workers who are under age 18 working ov...           0         0
# do workers under the age of 18 perform work tha...         584      2236
# All                                                       1752      6708
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# are any workers under age 18 subjected to the u...      0        833     474
# are any workers who are under age 18 working at...    161        833     474
# are any workers who are under age 18 working ov...    161          0       0
# do workers under the age of 18 perform work tha...    161        833       0
# All                                                   483       2499     948
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# are any workers under age 18 subjected to the u...        119     1802   6048
# are any workers who are under age 18 working at...        119     1802   6209
# are any workers who are under age 18 working ov...          0        0    161
# do workers under the age of 18 perform work tha...        119     1802   5735
# All                                                       357     5406  18153

# %% [markdown]
# ---

# %%
#4:
# these 2 discard code should not be executed:
# discardYear("are chemicals and hazardous substances properly labeled?","Nicaragua")
# discardYear("does the employer have chemical safety data sheets for the hazardous chemicals used in the workplace?","Nicaragua")
# "has the employer effectively trained workers who work with chemicals and hazardous substances?"

# replace(
#     ["has the employer effectively trained workers and supervisor who work with or are responsible for hazardous chemicals?",
# "has the employer effectively trained workers and supervisors who work with or are responsible for hazardous chemicals?",
# "has the employer effectively trained workers who work with chemicals and hazardous substances?",
# "has the employer trained all workers who work with chemicals and hazardous substances?"]
# )

# replace(
# ["has the employer taken action to assess, monitor, prevent and limit workers' exposure to chemicals and hazardous substances?",
# "has the employer taken action to prevent and limit workers' exposure to chemicals and hazardous substances?	",
# "has the employer taken action to, prevent and limit workers' exposure to chemicals and hazardous substances?"]
# )

# replace(
#     [
#         "does the employer keep chemical safety records for the hazardous chemicals used in the workplace?",
# "does the employer have chemical safety data sheets for all the hazardous chemicals used in the workplace?",
# "does the employer have chemical safety data sheets for the hazardous chemicals used in the workplace, and are the chemicals properly labelled?",
# "does the employer have chemical safety data sheets for the hazardous chemicals used in the workplace?	"
#     ]
# )


# replace([
# "does the employer keep a chemical inventory, and ensure that all chemicals and hazardous substances are properly labelled and have safety data sheets?",
# "does the employer keep an inventory of chemicals and hazardous substances used in the workplace?",
# "does the employer keep an inventory of hazardous chemicals used in the workplace?"
# ])

# replace(
#     [
#         "does the employer provide adequate washing facilities and cleaning materials in the event of exposure to hazardous chemicals?",
#         "does the employer provide adequate washing facilities and cleansing materials in the event of exposure to hazardous chemicals?"
#     ]
# )

# %%
tab(4)
# Out:
# chemicals and hazardous substances
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# are chemical mixing rooms properly equipped and...           0      2238
# are chemicals and hazardous substances properly...         584      2503
# are chemicals and hazardous substances properly...           0         0
# does the employer have the legally required lic...         357         0
# does the employer keep an inventory of hazardou...         584      2293
# does the employer keep chemical safety records ...         584      2279
# does the employer provide adequate washing faci...         584      2276
# does the employer provide information on the ch...           0         0
# has the employer appointed a chemical officer?               0         0
# has the employer prepared for response, control...           0      2270
# has the employer taken action to prevent and li...         584      2290
# has the employer trained all workers who work w...         584      2285
# storage of chemicals and hazardous substances              584      2503
# All                                                       4445     20937
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# are chemical mixing rooms properly equipped and...      0          0       0
# are chemicals and hazardous substances properly...    161          0       0
# are chemicals and hazardous substances properly...      0          0       0
# does the employer have the legally required lic...      0          0       0
# does the employer keep an inventory of hazardou...    161        833     474
# does the employer keep chemical safety records ...    161        851       0
# does the employer provide adequate washing faci...    161        833     474
# does the employer provide information on the ch...      0          0       0
# has the employer appointed a chemical officer?          0        834       0
# has the employer prepared for response, control...      0          0       0
# has the employer taken action to prevent and li...    161          0     474
# has the employer trained all workers who work w...    161        833       0
# storage of chemicals and hazardous substances         161        851     474
# All                                                  1127       5035    1896
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# are chemical mixing rooms properly equipped and...          0        0   2238
# are chemicals and hazardous substances properly...        122     1802   5172
# are chemicals and hazardous substances properly...          0     1802   1802
# does the employer have the legally required lic...          0        0    357
# does the employer keep an inventory of hazardou...        119     1802   6266
# does the employer keep chemical safety records ...        122     1802   5799
# does the employer provide adequate washing faci...        119     1802   6249
# does the employer provide information on the ch...        119        0    119
# has the employer appointed a chemical officer?              0        0    834
# has the employer prepared for response, control...          0        0   2270
# has the employer taken action to prevent and li...        122        0   3631
# has the employer trained all workers who work w...        122     1802   5787
# storage of chemicals and hazardous substances             122     1802   6497
# All                                                       967    12614  47021

# %%
#5:
# replace(
#     ["did the employer resolve collective disputes in compliance with legal requirements?",
# "did the employer resolve grievances and disputes in compliance with legal requirements?"]
# )

# replace(
#     ["do disciplinary measures comply with legal requirements?",
# "do the disciplinary measures comply with the company's by-laws approved by the ministry of labor?",
# "are disciplinary measures proportional to the seriousness of workers' misconduct?"]
# )

# replace([
#     "if union labour committee is formed, does employer meet worker representatives on a regular basis?",
#     "does the factory have a functioning participation committee?"
# ])

# replace([
# "does the factory have a functioning bipartite cooperation institution?",
# "does the factory have a functioning participation committee?"
# ])

# replace(
#     ["did the employer resolve grievances and disputes in compliance with legal requirements?",
# "did the employer resolve individual grievances and disputes in compliance with legal requirements?"]
# )

# replace(["does the employer comply with requirements regarding shop stewards?",
#          "does the factory have a functioning participation committee?"], "have participation committee or shop steward")

# assign("did the employer resolve collective disputes in compliance with legal requirements?")

# %%
tab(5)
# Out:
# dialogue, discipline and disputes
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# bullying harassment                                        584      2503
# did the employer resolve grievances and dispute...         584      2503
# did the factory consult the measures (suspensio...           0         0
# do disciplinary measures comply with legal requ...         584      2236
# does dialogue at the workplace take place in co...           0         0
# does the factory have a qualified welfare officer?         584         0
# has the employer complied with arbitration awards?         357      2503
# has the employer complied with court orders ari...           0      2237
# has the employer complied with final conciliati...           0      2503
# have participation committee or shop steward               584      2411
# if the ministry of labor has delivered a resolu...           0         0
# All                                                       3277     16896
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# bullying harassment                                   161        851     474
# did the employer resolve grievances and dispute...    161        833     474
# did the factory consult the measures (suspensio...      0          0       0
# do disciplinary measures comply with legal requ...      0        833     474
# does dialogue at the workplace take place in co...      0          0       0
# does the factory have a qualified welfare officer?      0          0       0
# has the employer complied with arbitration awards?      0          0       0
# has the employer complied with court orders ari...      0          0       0
# has the employer complied with final conciliati...      0          0       0
# have participation committee or shop steward            0        851     474
# if the ministry of labor has delivered a resolu...      0          0       0
# All                                                   322       3368    1896
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# bullying harassment                                       122     1802   6497
# did the employer resolve grievances and dispute...          0     1802   6357
# did the factory consult the measures (suspensio...          3        0      3
# do disciplinary measures comply with legal requ...        119     1802   6048
# does dialogue at the workplace take place in co...          0     1802   1802
# does the factory have a qualified welfare officer?          0        0    584
# has the employer complied with arbitration awards?          0        0   2860
# has the employer complied with court orders ari...          0        0   2237
# has the employer complied with final conciliati...          0        0   2503
# have participation committee or shop steward                0        0   4320
# if the ministry of labor has delivered a resolu...          3        0      3
# All                                                       247     7208  33214

# %%
#6:
# undo("does the employer pay workers correctly during daily breaks?")

# replace([
#     "does the employer pay workers correctly during the daily break?",
#     "does the employer pay workers correctly during daily breaks?"
#     ])

# replace(
#     [
# "does the employer pay workers correctly for annual leave (14 or 21 days)?",
# "does the employer pay workers correctly for annual leave (vacation)?",
# "does the employer pay workers correctly for annual leave?",
# "does the employer pay workers correctly for legally required annual leave?",
# "does the employer pay workers correctly during annual leave?"
#     ], "legal pay for annual leave"
# )

# replace([
#     "paid leave for breastfeed",
#     "does the employer pay workers for one hour breastfeeding break per day?"
# ])

# replace([
#     "does the employer provide paid sick leave as required by the factory’s internal regulations, or if there are no internal regulations, according to the ministry's practice?",
# "paid sick leave","does the employer settle claims for sick leave and maternity leave within 3 working days?",
# "does the employer pay workers correctly during medical leave?"
# ]
# )

# replace([
#     "does the employer pay workers correctly during suspensions of work?",
#     "does the employer pay workers correctly during work stoppages?	"
# ],"pay for work stoppage")

replace([
    "does the employer pay workers correctly during personal leave?",
    "does the employer pay workers correctly for personal leave?"
])

# %%
tab(6)
# Out:
# paid leave
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# do pregnant workers receive correct payment whe...           0         0
# do workers receive correct payment during sick ...           0         0
# does the employer pay any workers incorrectly f...           0         0
# does the employer pay for paternity leave when ...           0         0
# does the employer pay women workers for 30 minu...           0         0
# does the employer pay workers correctly during ...         584         0
# does the employer pay workers correctly during ...           0         0
# does the employer pay workers correctly during ...           0      2503
# does the employer pay workers correctly for non...           0         0
# does the employer pay workers correctly for pai...         584      2243
# does the employer pay workers correctly for per...           0         0
# does the employer pay workers correctly for wee...           0         0
# does the employer pay workers correctly when th...           0         0
# does the employer pay workers correctly when th...           0         0
# does the employer pay workers who are subpoenae...           0         0
# does the employer provide 1 hour of paid time o...           0         0
# legal pay for annual leave                                 584      2503
# paid leave for breastfeed                                    0      2259
# paid sick leave                                            584      2503
# pay for work stoppage                                      584      2503
# payment for maternity leave                                584      2503
# All                                                       3504     17017
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# do pregnant workers receive correct payment whe...      0          0       0
# do workers receive correct payment during sick ...      0          0       0
# does the employer pay any workers incorrectly f...     60          0       0
# does the employer pay for paternity leave when ...      0          0       0
# does the employer pay women workers for 30 minu...      0          0       0
# does the employer pay workers correctly during ...      0          0       0
# does the employer pay workers correctly during ...     81          0       0
# does the employer pay workers correctly during ...      0          0       0
# does the employer pay workers correctly for non...      0          0       0
# does the employer pay workers correctly for pai...    133        851     474
# does the employer pay workers correctly for per...      0          0       0
# does the employer pay workers correctly for wee...    101          0       0
# does the employer pay workers correctly when th...      0        833       0
# does the employer pay workers correctly when th...      0        839       0
# does the employer pay workers who are subpoenae...      0          0       0
# does the employer provide 1 hour of paid time o...      0          0       0
# legal pay for annual leave                            161        851     474
# paid leave for breastfeed                             161        833     474
# paid sick leave                                       142        851     474
# pay for work stoppage                                   0        851     474
# payment for maternity leave                           161        851     474
# All                                                  1000       6760    2844
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# do pregnant workers receive correct payment whe...          0     1802   1802
# do workers receive correct payment during sick ...          0     1802   1802
# does the employer pay any workers incorrectly f...          0        0     60
# does the employer pay for paternity leave when ...        117     1802   1919
# does the employer pay women workers for 30 minu...          0     1802   1802
# does the employer pay workers correctly during ...          0        0    584
# does the employer pay workers correctly during ...        119        0    200
# does the employer pay workers correctly during ...          0        0   2503
# does the employer pay workers correctly for non...        119        0    119
# does the employer pay workers correctly for pai...        119     1802   6206
# does the employer pay workers correctly for per...        122     1802   1924
# does the employer pay workers correctly for wee...          0        0    101
# does the employer pay workers correctly when th...          0        0    833
# does the employer pay workers correctly when th...          0        0    839
# does the employer pay workers who are subpoenae...          2        0      2
# does the employer provide 1 hour of paid time o...          0     1775   1775
# legal pay for annual leave                                122     1802   6497
# paid leave for breastfeed                                 119     1802   5648
# paid sick leave                                           122     1775   6451
# pay for work stoppage                                     122     1802   6336
# payment for maternity leave                               120     1802   6495
# All                                                      1203    21570  53898

# %%
df[(df.QCleaned=="paid sick leave") & (df.Country=="Vietnam")].Q.value_counts()
# Out:
# does the employer submit claims for sick leave and maternity leave to the social insurance agency within 10 days?    1555
# does the employer settle claims for sick leave and maternity leave within 3 working days?                             247
# Name: Q, dtype: int64

# %%
#7:
# replace([
#     "are noise levels acceptable?",
# "are noise levels measured by the employer and in line with applicable standard?	"
# ])

# replace([
#     "is the temperature and ventilation aceptable?",
# "is the temperature in the workplace acceptable?","is the workplace adequately ventilated?",
# "is the workplace climate measured by the employer, and in line with applicable standards?"
# ],"temperature and ventilation acceptable")

# %%
tab(7)
# Out:
# working environment
# Country                                  Bangladesh  Cambodia  Haiti  \
# QCleaned
# are noise levels acceptable?                    584      2371    161
# is the workplace adequately lit?                584      2443    161
# is the workplace adequately ventilated?           0         0      0
# is the workplace clean and tidy?                584      2271    156
# temperature and ventilation acceptable          584      2406    161
# All                                            2336      9491    639
#
# Country                                  Indonesia  Jordan  Nicaragua  \
# QCleaned
# are noise levels acceptable?                   833     474        122
# is the workplace adequately lit?               833     474        122
# is the workplace adequately ventilated?          0       0          0
# is the workplace clean and tidy?               480     474        117
# temperature and ventilation acceptable         834     474        122
# All                                           2980    1896        483
#
# Country                                  Vietnam    All
# QCleaned
# are noise levels acceptable?                1802   6347
# is the workplace adequately lit?            1802   6419
# is the workplace adequately ventilated?     1802   1802
# is the workplace clean and tidy?            1802   5884
# temperature and ventilation acceptable      1802   6383
# All                                         9010  26835

# %%
#8:

# replace([
#     "gender a factor in termination",
#     "is gender or marital status a factor in decisions regarding opportunities for promotion or access to training?"
# ])

# replace([
#     "does the employer terminate workers who are on maternity leave or force them to resign?",
#     "is gender or marital status a factor in the employer's decisions regarding termination or retirement of workers?"
# ],"maternity a factor in termination")

# %%
tab(8)
# Out:
# gender
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# does the employer change the employment status,...         584      2236
# gender a factor in promotion                               584      2503
# gender a factor in termination                             584      2503
# gender a factor regarding pay                              584      2503
# gender discrimination on conditions of work                584      2503
# is an applicant's gender a factor in hiring dec...         584      2503
# job announcements refer to gender                          584      2503
# maternity a factor in termination                            0      2503
# maternity leave included in continous service              584      2236
# requires pregnancy test/contraceptive                      584      2236
# sexual harassment                                          584      2503
# terminate workers due to pregnancy or maternity...         584      2503
# All                                                       6424     29235
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# does the employer change the employment status,...    161        833       0
# gender a factor in promotion                           58        833       0
# gender a factor in termination                        161        851       0
# gender a factor regarding pay                         161        833     474
# gender discrimination on conditions of work           161        851     474
# is an applicant's gender a factor in hiring dec...    161        851       0
# job announcements refer to gender                     161          0     474
# maternity a factor in termination                     161          0       0
# maternity leave included in continous service         161        833     474
# requires pregnancy test/contraceptive                 161        851     474
# sexual harassment                                     161        851     474
# terminate workers due to pregnancy or maternity...    161        851     474
# All                                                  1829       8438    3318
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# does the employer change the employment status,...        122     1802   5738
# gender a factor in promotion                              119     1802   5899
# gender a factor in termination                            122     1081   5302
# gender a factor regarding pay                             119     1802   6476
# gender discrimination on conditions of work               122     1802   6497
# is an applicant's gender a factor in hiring dec...        122     1802   6023
# job announcements refer to gender                         119     1802   5643
# maternity a factor in termination                           0        0   2664
# maternity leave included in continous service             119     1802   6209
# requires pregnancy test/contraceptive                     119     1802   6227
# sexual harassment                                         122     1802   6497
# terminate workers due to pregnancy or maternity...        122     1802   6497
# All                                                      1327    19101  69672

# %% [markdown]
# ---
# [haiti issue](./min-wages.png)

# %%
#9:
# replace(["does the employer pay piece rate workers correctly for ordinary hours of work when their piece rate earnings exceed minimum wage?",
# "does the employer pay piece rate workers correctly for ordinary hours of work?"])

# replace([
#     "does the employer pay piece rate workers correctly for ordinary hours of work?",
# "does the employer pay piece rate workers correctly for regular hours of work?",
# "are piece-rate workers paid correctly for ordinary hours of work?"
# ])

# undo("does the employer pay at least 90 gourdes per day for ordinary hours of work to apprentices?")


# replace(["does the employer pay at least 200 gourdes per day for ordinary hours of work to apprentices?",
# "does the employer pay at least 140 gourdes per day for ordinary hours of work to apprentices?",
# "does the employer pay at least 120 gourdes per day for ordinary hours of work to apprentices?",
# "does the employer pay at least 96 gourdes per day for ordinary hours of work to apprentices?",
# "does the employer pay at least 96 gourdes per day for ordinary hours of work to apprentices (120 gourdes as of 01 may 2016)?",  
# "does the employer pay at least 90 gourdes per day for ordinary hours of work to apprentices?",      
# "does the employer pay at least 90 gourdes (96 gourdes as of may 1st 2015) per day for ordinary hours of work to apprentices?"],
# "minimum pay to apprentices")

# replace(["does the employer pay at least 300 gourdes per day for ordinary hours of work to temporary workers?",
# "does the employer pay at least 240 gourdes per day for ordinary hours of work to temporary workers?",
# "does the employer pay at least 350 gourdes per day for ordinary hours of work to temporary workers?",
# "does the employer pay at least 500 gourdes per day for ordinary hours of work to temporary workers?",                                 
# "does the employer pay at least 240 gourdes per day for ordinary hours of work to temporary workers (300 gourdes as of 01 may 2016)?",   
# "does the employer pay at least 225 gourdes (240 gourdes as of may 1st, 2015) per day for ordinary hours of work to temporary workers?", 
# "does the employer pay at least 200 gourdes (225 gourdes as of may 1st, 2014) per day for ordinary hours of work to temporary workers?"],
# "minimum pay to temporary workers")

# replace(
#     ["does the employer pay at least minimum wage for all types of workers other than regular workers?",
#     "does the employer pay at least minimum wage for temporary and probationary workers?",
#     "does the employer pay higher than district minimum wage for ordinary hours of work to permanent (pkwtt) and non-permanent workers (pkwt) who have worked for more than 1 year?",
#     "minimum pay to temporary workers"]
# )

# %%
tab(9)
# Out:
# minimum wages/piece rate wages
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# are piece-rate workers paid correctly for ordin...         584      2503
# does the employer establish a wage structure an...           0         0
# does the employer pay apprentices the wage agre...         584         0
# does the employer pay at least 7% higher than t...           0         0
# is the piece rate set at a level that permits w...           0      2284
# minimum pay to apprentices                                   0         0
# minimum pay to temporary workers                           584      2503
# minimum wages for regular workers                          584      2503
# All                                                       2336      9793
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# are piece-rate workers paid correctly for ordin...    126        833     474
# does the employer establish a wage structure an...      0        480       0
# does the employer pay apprentices the wage agre...      0          0       0
# does the employer pay at least 7% higher than t...      0          0       0
# is the piece rate set at a level that permits w...      0          0       0
# minimum pay to apprentices                            161          0       0
# minimum pay to temporary workers                      161        833     474
# minimum wages for regular workers                     161        851     474
# All                                                   609       2997    1422
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# are piece-rate workers paid correctly for ordin...        119     1802   6441
# does the employer establish a wage structure an...          0        0    480
# does the employer pay apprentices the wage agre...          0     1802   2386
# does the employer pay at least 7% higher than t...          0     1802   1802
# is the piece rate set at a level that permits w...          0        0   2284
# minimum pay to apprentices                                  0        0    161
# minimum pay to temporary workers                          121     1802   6478
# minimum wages for regular workers                         122     1802   6497
# All                                                       362     9010  26529

# %%
#10:
# df.loc[df.Q=="does the employer provide required leave for personal reasons?", "QCleaned"]="does the employer provide required leave for personal reasons?"

# replace(
#     ["does the employer provide required annual leave to workers with at least 12 months' experience?",
# "does the employer provide required annual leave?	"]
# )

# replace([
#     "does the employer provide workers at least 14 days of paid annual leave per year, or 21 days after 5 years of service?",
# "does the employer provide workers at least 14 working days of annual leave per year, or 21 working days after 5 years of service?"
# ])

# replace([
#     "does the employer provide required maternity leave?",
#     "does the employer provide the correct amount of time off for maternity rest, including in cases of miscarriage?"
# ])

# replace([
#     "does the employer provide required sick leave?	",
#     "does the employer comply with the entitlement to sick leave and other types of leave that are covered by social insurance?	"
# ])

# replace([
#     "does the employer give workers at least 18 days of annual leave per year and an extra day of annual leave for every three years of service?",
#     "does the employer provide 12 days of annual leave per year?",
#     "does the employer provide required annual leave?",
#     "does the employer provide workers at least 14 days of paid annual leave per year, or 21 days after 5 years of service?",
#     "does the employer provide 15 days of annual leave to workers for every six months of continuous service in the factory?"
# ])

# df.loc[(df.QCleaned=="does the employer provide required annual leave?") & (df.Country=="Nicaragua"),"QCleaned"]="does the employer provide other types of required leave?"

# replace([
#     "does the employer provide required annual leave?",
#     "does the employer provide 15 days of annual leave to workers for every six months of continuous service in the factory?"
# ])

# replace([
#     "can female workers take time off when they feel pain during the first two days of menstruation and they notify the employer?",
# "does the employer allow workers to take 30 minutes rest during their period?"
# ],"period break")

# df.loc[df.Q=="does the employer provide required personal leave?","QCleaned"]="does the employer provide required personal leave?"

# replace(["does the employer provide required leave for personal reasons?",
#          "does the employer provide required personal leave?"])

# %%
tab(10)
# Out:
# leave
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# are pregnant workers provided time off for pren...           0         0
# does the employer give workers up to 7 days of ...           0      2503
# does the employer provide 1 hour off to elderly...           0         0
# does the employer provide 10 days of casual lea...         584         0
# does the employer provide at least 15 days of a...           0         0
# does the employer provide other types of requir...           0         0
# does the employer provide required annual leave?           584      2503
# does the employer provide required breastfeedin...           0      2294
# does the employer provide required maternity le...         584      2503
# does the employer provide required personal leave?           0         0
# does the employer provide required sick leave?             584      2503
# does the employer provide required time off for...           0         0
# does the employer provide workers 11 festival h...         584         0
# if workers are paid for annual leave instead of...           0         0
# period break                                                 0         0
# All                                                       2920     12306
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# are pregnant workers provided time off for pren...      0          0       0
# does the employer give workers up to 7 days of ...      0          0       0
# does the employer provide 1 hour off to elderly...      0          0       0
# does the employer provide 10 days of casual lea...      0          0       0
# does the employer provide at least 15 days of a...    161          0       0
# does the employer provide other types of requir...      0          0       0
# does the employer provide required annual leave?      161        851     474
# does the employer provide required breastfeedin...    101        833     474
# does the employer provide required maternity le...    161        851     474
# does the employer provide required personal leave?      0          0       0
# does the employer provide required sick leave?        161        851     474
# does the employer provide required time off for...      0        851       0
# does the employer provide workers 11 festival h...      0          0       0
# if workers are paid for annual leave instead of...      0          0       0
# period break                                            0        833       0
# All                                                   745       5070    1896
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# are pregnant workers provided time off for pren...          0     1802   1802
# does the employer give workers up to 7 days of ...          0        0   2503
# does the employer provide 1 hour off to elderly...          0     1775   1775
# does the employer provide 10 days of casual lea...          0        0    584
# does the employer provide at least 15 days of a...          0        0    161
# does the employer provide other types of requir...          2        0      2
# does the employer provide required annual leave?          122     1802   6497
# does the employer provide required breastfeedin...        119     1802   5623
# does the employer provide required maternity le...        122     1802   6497
# does the employer provide required personal leave?        122     1802   1924
# does the employer provide required sick leave?            122     1802   6497
# does the employer provide required time off for...        120     1802   2773
# does the employer provide workers 11 festival h...          0        0    584
# if workers are paid for annual leave instead of...        119        0    119
# period break                                                0     1802   2635
# All                                                       848    16191  39976

# %%
#11:
# replace(["does the employer provide round trip transport for female workers who work between 11 p.m. and 5 a.m?",
# "does the employer provide transport home or a place to sleep for workers who finish work between 22:00 and 05:00?"])

# replace([
#     "are the welfare fund and workers’ welfare foundation fund used in the manner determined by the fund board of trustees?",
#     "are the workers' participation and welfare funds used and distributed as required?"
# ])

# df.loc[df.Q=="does the employer pay the required employer contribution to ona?","QCleaned"]="does the employer pay the required employer contribution to ona?"

# df.loc[df.Q=="does the employer pay 3% of workers' basic salary to ofatma for maternity and health insurance?","QCleaned"]="pay for maternity insurance"

# undo(
#     "does the employer correctly calculate and send the employer contribution to the social security corporation?"
# )

# undo("does the employer pay the required contributions for social insurance (bpjs ketenagakerjaan) and health care funds (bpjs kesehatan) to bpjs?")

# replace([
#     "Does the employer pay the required contributions for social insurance (BPJS Ketenagakerjaan) and health care funds (BPJS Kesehatan) to BPJS?".lower(),
#     "Does the employer comply with all requirements related to National healthcare funds (BPJS kesehatan), including registering workers, paying employer contributions, and collecting and forwarding workers’ contribution?".lower()
# ],"pay social insurance")

# replace([
#     "Does the employer collect and forward all workers' contributions for social insurance (BPJS Ketenagakerjaan) and health care funds (BPJS Kesehatan)?".lower(),
#     "Does the employer comply with all requirements related to national social insurance (BPJS Ketenagakerjaan), including registering workers, paying employer contributions, and collecting and forwarding workers' contributions?".lower()
# ],"forward social insurance")

# replace([
#     "Does the employer pay all workers who work regularly the correct attendance bonus during leave legally required by law?".lower(),
#     "Does the employer pay all workers who work regularly the correct attendance bonus when workers take annual leave?".lower()
# ])

# df.loc[df.Q=="if a provident fund has been established, does the employer match the contributions made by workers?","QCleaned"]="if a provident fund has been established, does the employer match the contributions made by workers?"
# replace(['has the employer established a provident fund upon written demand by workers?'],"collect and deposit workers' contributions into the fund")
# df.loc[df.Q=="has the employer established a provident fund upon written demand by workers?","QCleaned"]="has the employer established a provident fund upon written demand by workers?"

# replace([
#     "does the employer pay workers two festival bonuses per year?",
#     "does the employer pay workers the religious holiday allowance?"
# ])

# %%
collapse(
    "does the employer pay the required amount each year into the workers' participation fund?",
    "Bangladesh"
)
# Out:
# has the employer properly established a workers' participation fund and welfare fund, and paid the required amount into the funds each year?    566
# does the employer pay the required amount each year into the welfare fund and workers’ welfare foundation fund?                                  18
# does the employer pay the required amount each year into the workers' participation fund?                                                        18
# Name: Q, dtype: int64

# %%
tab(11)
# Out:
# social security and other benefits
# Country                                             Bangladesh  Cambodia  \
# QCleaned
# are the workers' participation and welfare fund...         584         0
# collect and deposit workers' contributions into...         584         0
# do workers receive required distributions from ...          18         0
# does the employer collect and forward workers' ...           0         0
# does the employer comply with other wage payments?          18         0
# does the employer comply with requirements when...           0         0
# does the employer correctly calculate and send ...           0         0
# does the employer correctly calculate, collect,...           0         0
# does the employer forward workers contributions...           0         0
# does the employer forward workers contributions...           0         0
# does the employer pay 16% of total wages to the...           0         0
# does the employer pay 2% of the gross payroll t...           0         0
# does the employer pay 3% of workers' salary to ...           0         0
# does the employer pay all workers the correct m...           0      2503
# does the employer pay all workers who work regu...           0      2503
# does the employer pay all workers who work regu...           0      1153
# does the employer pay all workers who work regu...           0      1153
# does the employer pay the correct attendance bo...           0      2503
# does the employer pay the correct compensation ...         584         0
# does the employer pay the required amount each ...         602         0
# does the employer pay the required amount into ...         357         0
# does the employer pay the required employer con...           0         0
# does the employer pay the required employer con...           0      2503
# does the employer pay udc workers the correct s...           0       269
# does the employer pay workers a 13th month of w...           0         0
# does the employer pay workers the correct compe...         357      2503
# does the employer pay workers the correct senio...           0      2503
# does the employer pay workers their annual sala...           0         0
# does the employer pay workers two festival bonu...         566         0
# does the employer pay workers who are not cover...           0         0
# does the employer provide compulsory group insu...         584         0
# does the employer provide nutritious food and d...           0         0
# does the employer provide round trip transport ...           0      2250
# forward social insurance                                     0         0
# has the employer established a provident fund u...          18         0
# if a provident fund has been established, does ...          18         0
# paid sick leave                                              0         0
# pay for maternity insurance                                  0         0
# pay social insurance                                         0         0
# All                                                       4290     19843
#
# Country                                             Haiti  Indonesia  Jordan  \
# QCleaned
# are the workers' participation and welfare fund...      0          0       0
# collect and deposit workers' contributions into...      0          0       0
# do workers receive required distributions from ...      0          0       0
# does the employer collect and forward workers' ...      0          0       0
# does the employer comply with other wage payments?      0          0       0
# does the employer comply with requirements when...      0          0       0
# does the employer correctly calculate and send ...      0          0     474
# does the employer correctly calculate, collect,...      0          0     474
# does the employer forward workers contributions...    161          0       0
# does the employer forward workers contributions...    161          0       0
# does the employer pay 16% of total wages to the...      0          0       0
# does the employer pay 2% of the gross payroll t...      0          0       0
# does the employer pay 3% of workers' salary to ...    161          0       0
# does the employer pay all workers the correct m...      0          0       0
# does the employer pay all workers who work regu...      0          0       0
# does the employer pay all workers who work regu...      0          0       0
# does the employer pay all workers who work regu...      0          0       0
# does the employer pay the correct attendance bo...      0          0       0
# does the employer pay the correct compensation ...      0          0       0
# does the employer pay the required amount each ...      0          0       0
# does the employer pay the required amount into ...      0          0       0
# does the employer pay the required employer con...    161          0       0
# does the employer pay the required employer con...      0          0       0
# does the employer pay udc workers the correct s...      0          0       0
# does the employer pay workers a 13th month of w...      0          0       0
# does the employer pay workers the correct compe...      0          0       0
# does the employer pay workers the correct senio...      0          0     474
# does the employer pay workers their annual sala...    161          0       0
# does the employer pay workers two festival bonu...      0        851       0
# does the employer pay workers who are not cover...      0          0       0
# does the employer provide compulsory group insu...      0          0       0
# does the employer provide nutritious food and d...      0        833       0
# does the employer provide round trip transport ...      0        834       0
# forward social insurance                                0        851       0
# has the employer established a provident fund u...      0          0       0
# if a provident fund has been established, does ...      0          0       0
# paid sick leave                                         0          0       0
# pay for maternity insurance                           161          0       0
# pay social insurance                                    0        851       0
# All                                                   966       4220    1422
#
# Country                                             Nicaragua  Vietnam    All
# QCleaned
# are the workers' participation and welfare fund...          0        0    584
# collect and deposit workers' contributions into...          0        0    584
# do workers receive required distributions from ...          0        0     18
# does the employer collect and forward workers' ...        120     1802   1922
# does the employer comply with other wage payments?          0        0     18
# does the employer comply with requirements when...          0     1802   1802
# does the employer correctly calculate and send ...          0        0    474
# does the employer correctly calculate, collect,...          0        0    474
# does the employer forward workers contributions...          0        0    161
# does the employer forward workers contributions...          0        0    161
# does the employer pay 16% of total wages to the...        124        0    124
# does the employer pay 2% of the gross payroll t...        122        0    122
# does the employer pay 3% of workers' salary to ...          0        0    161
# does the employer pay all workers the correct m...          0        0   2503
# does the employer pay all workers who work regu...          0        0   2503
# does the employer pay all workers who work regu...          0        0   1153
# does the employer pay all workers who work regu...          0        0   1153
# does the employer pay the correct attendance bo...          0        0   2503
# does the employer pay the correct compensation ...          0        0    584
# does the employer pay the required amount each ...          0        0    602
# does the employer pay the required amount into ...          0        0    357
# does the employer pay the required employer con...          0        0    161
# does the employer pay the required employer con...          0        0   2503
# does the employer pay udc workers the correct s...          0        0    269
# does the employer pay workers a 13th month of w...        122        0    122
# does the employer pay workers the correct compe...          0        0   2860
# does the employer pay workers the correct senio...          0        0   2977
# does the employer pay workers their annual sala...          0        0    161
# does the employer pay workers two festival bonu...          0        0   1417
# does the employer pay workers who are not cover...          0     1802   1802
# does the employer provide compulsory group insu...          0        0    584
# does the employer provide nutritious food and d...          0        0    833
# does the employer provide round trip transport ...          0        0   3084
# forward social insurance                                    0        0    851
# has the employer established a provident fund u...          0        0     18
# if a provident fund has been established, does ...          0        0     18
# paid sick leave                                             0       27     27
# pay for maternity insurance                                 0        0    161
# pay social insurance                                        0        0    851
# All                                                       488     5433  36662

# %%
df.to_csv("r1.csv", index=False)
